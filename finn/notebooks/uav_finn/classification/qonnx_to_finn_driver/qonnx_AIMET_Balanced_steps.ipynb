# %% [markdown]
# # Folders setup

# %%
models_folder = './models/aimet_balanced/'
aimet_ori = models_folder + 'BED_classifier__best_mean_F1__AIMET_Balanced__BIPOLAR_Out__QONNX.onnx'

# %% [markdown]
# # Model Clean

# %%
from finn.util.visualization import showSrc, showInNetron
from qonnx.util.cleanup import cleanup as qonnx_cleanup

# %%
qonnx_clean_filename = models_folder + '01_clean.onnx'
qonnx_cleanup(aimet_ori, out_file=qonnx_clean_filename)

# %%
showInNetron(aimet_ori)
# Out:
# Serving './models/aimet_balanced/BED_classifier__best_mean_F1__AIMET_Balanced__BIPOLAR_Out__QONNX.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
showInNetron(qonnx_clean_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/01_clean.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Compare All Outputs

# %%
from qonnx.core.modelwrapper import ModelWrapper
import qonnx.core.onnx_exec as oxe

import numpy as np

# %%
test_ip = np.random.randint(low=0, high=256, size=(1, 3, 230, 230)) / 255.
test_ip = test_ip.astype(np.float32)

# %%
clean_model = ModelWrapper(qonnx_clean_filename)

# %%
input_dict = {"global_in": test_ip}
output_dict = oxe.execute_onnx(clean_model, input_dict)
produced_clean_qonnx = output_dict[list(output_dict.keys())[0]]
produced_clean_qonnx
# Out:
# array([[-1., -1.]], dtype=float32)

# %% [markdown]
# # Convert to FINN

# %%
from finn.transformation.qonnx.convert_qonnx_to_finn import ConvertQONNXtoFINN
from qonnx.transformation.infer_shapes import InferShapes
from qonnx.transformation.fold_constants import FoldConstants
from qonnx.transformation.general import GiveReadableTensorNames, GiveUniqueNodeNames, RemoveStaticGraphInputs

# %%
model = ModelWrapper(qonnx_clean_filename)
model = model.transform(ConvertQONNXtoFINN())
model = model.transform(InferShapes())
model = model.transform(FoldConstants())
model = model.transform(GiveUniqueNodeNames())
model = model.transform(GiveReadableTensorNames())
model = model.transform(RemoveStaticGraphInputs())

# %%
finn_tidy = models_folder + '02_finn_tidy.onnx'
model.save(finn_tidy)

# %%
showInNetron(finn_tidy)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/02_finn_tidy.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # PreProcess

# %%
import torch
from finn.util.pytorch import ToTensor
from qonnx.transformation.merge_onnx_models import MergeONNXModels
from qonnx.core.datatype import DataType
from brevitas.export import export_qonnx

# %%
model = ModelWrapper(finn_tidy)
global_inp_name = model.graph.input[0].name
ishape = model.get_tensor_shape(global_inp_name)
# preprocessing: torchvision's ToTensor divides uint8 inputs by 255
totensor_pyt = ToTensor()
chkpt_preproc_name = models_folder + "./prepro_node.onnx"
export_qonnx(totensor_pyt, torch.randn(ishape), chkpt_preproc_name)
qonnx_cleanup(chkpt_preproc_name, out_file=chkpt_preproc_name)
pre_model = ModelWrapper(chkpt_preproc_name)
pre_model = pre_model.transform(ConvertQONNXtoFINN())

# join preprocessing and core model
model = model.transform(MergeONNXModels(pre_model))
# add input quantization annotation: UINT8 for all BNN-PYNQ models
global_inp_name = model.graph.input[0].name
model.set_tensor_datatype(global_inp_name, DataType["UINT8"])
# Out:
# /home/gmoreno/uav/finn/deps/qonnx/src/qonnx/transformation/merge_onnx_models.py:70: UserWarning: [MergeONNXModels] opsets for models to merge differ: 14 vs 17, output model will use opset 17
#   warnings.warn(
# /home/gmoreno/uav/finn/deps/qonnx/src/qonnx/transformation/infer_data_layouts.py:127: UserWarning: Assuming 4D input is NCHW
#   warnings.warn("Assuming 4D input is NCHW")

# %%
from qonnx.transformation.infer_datatypes import InferDataTypes

# %% [markdown]
# ### Save prepro again after tidy

# %%
model = model.transform(InferShapes())
model = model.transform(FoldConstants())
model = model.transform(GiveUniqueNodeNames())
model = model.transform(GiveReadableTensorNames())
model = model.transform(InferDataTypes())
model = model.transform(RemoveStaticGraphInputs())

# %%
finn_prepro = models_folder + '03_finn_prepro.onnx'
model.save(finn_prepro)

# %%
showInNetron(finn_prepro)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/03_finn_prepro.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Streamline

# %%
from qonnx.transformation.lower_convs_to_matmul import LowerConvsToMatMul
from qonnx.transformation.change_datalayout import ChangeDataLayoutQuantAvgPool2d
from qonnx.transformation.infer_data_layouts import InferDataLayouts
from qonnx.transformation.general import RemoveUnusedTensors

from finn.transformation.streamline import Streamline
import finn.transformation.streamline.absorb as absorb
from finn.transformation.streamline.reorder import MakeMaxPoolNHWC, MoveScalarLinearPastInvariants

# %%
model = ModelWrapper(finn_prepro)
model = model.transform(MoveScalarLinearPastInvariants())
model = model.transform(Streamline())
model = model.transform(LowerConvsToMatMul())
model = model.transform(MakeMaxPoolNHWC())
model = model.transform(ChangeDataLayoutQuantAvgPool2d())
model = model.transform(absorb.AbsorbTransposeIntoMultiThreshold())
model = model.transform(Streamline())
model = model.transform(InferDataLayouts())
model = model.transform(RemoveUnusedTensors())
# Out:
# /home/gmoreno/uav/finn/src/finn/transformation/streamline/absorb.py:166: RuntimeWarning: divide by zero encountered in divide
#   Tnew = T / A.reshape(-1, 1)

# %%
finn_streamline = models_folder + '04_finn_streamline.onnx'
model.save(finn_streamline)

# %%
showInNetron(finn_streamline)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/04_finn_streamline.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # HW Layers

# %%
from finn.util.basic import pynq_part_map
# change this if you have a different PYNQ board, see list above
pynq_board = "Pynq-Z1"
fpga_part = pynq_part_map[pynq_board]
target_clk_ns = 10

# %%
print(pynq_part_map)
print(fpga_part)
# Out:
# {'Ultra96': 'xczu3eg-sbva484-1-e', 'Ultra96-V2': 'xczu3eg-sbva484-1-i', 'Pynq-Z1': 'xc7z020clg400-1', 'Pynq-Z2': 'xc7z020clg400-1', 'ZCU102': 'xczu9eg-ffvb1156-2-e', 'ZCU104': 'xczu7ev-ffvc1156-2-e', 'ZCU111': 'xczu28dr-ffvg1517-2-e', 'RFSoC2x2': 'xczu28dr-ffvg1517-2-e', 'RFSoC4x2': 'xczu48dr-ffvg1517-2-e', 'KV260_SOM': 'xck26-sfvc784-2LV-c'}
# xc7z020clg400-1

# %%
import finn.transformation.fpgadataflow.convert_to_hw_layers as to_hw
from finn.transformation.fpgadataflow.create_dataflow_partition import (
    CreateDataflowPartition,
)
from finn.transformation.move_reshape import RemoveCNVtoFCFlatten

from qonnx.custom_op.registry import getCustomOp

# %% [markdown]
# ### Set Datatype of Multithresholds that were not infered properly
#
# All MultiThresholds following a convolution splitted by Spatial SVD are not inferred properly.
# - Conv1 (3,1) -> QuantIdentity -----------------> NOT OK
# - Conv2 (1,3) -> BatchNorm -> ReLU -------------> OK

# %%
model = ModelWrapper(finn_streamline)

# %%
Multithreshold_node = model.get_nodes_by_op_type("MultiThreshold")

# %%
for node in Multithreshold_node:
    if model.get_tensor_datatype(node.input[1]) == "FLOAT32":
        print(f'Node with Float32 annotation {node.name}')
        model.set_tensor_datatype(node.input[1], DataType["INT32"])
        print(model.get_tensor_datatype(node.input[1]))
# Out:
# Node with Float32 annotation MultiThreshold_2
# INT32
# Node with Float32 annotation MultiThreshold_5
# INT32
# Node with Float32 annotation MultiThreshold_8
# INT32
# Node with Float32 annotation MultiThreshold_16
# INT32

# %%
finn_set_datatype = models_folder + '05_finn_set_datatype.onnx'

# %%
model.save(finn_set_datatype)

# %%
showInNetron(finn_set_datatype)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/05_finn_set_datatype.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Change last Bipolar Node to Binary

# %%
model = ModelWrapper(finn_set_datatype)

# %%
Multithreshold_node = model.get_nodes_by_op_type("MultiThreshold")

# %%
# for node in Multithreshold_node:
#     if node.name == "MultiThreshold_19":
#         node_inst = getCustomOp(node)
#         print(node_inst.get_nodeattr("out_scale"))
#         node_inst.set_nodeattr("out_dtype", "BINARY")
#         node_inst.set_nodeattr("out_scale", 1.0)
#         node_inst.set_nodeattr("out_bias", 0.0)
#         print(node)
# Out:
# 2.0
# input: "MatMul_18_out0"
# input: "MultiThreshold_19_param0"
# output: "global_out"
# name: "MultiThreshold_19"
# op_type: "MultiThreshold"
# attribute {
#   name: "out_dtype"
#   s: "BINARY"
#   type: STRING
# }
# attribute {
#   name: "out_scale"
#   f: 1.0
#   type: FLOAT
# }
# attribute {
#   name: "out_bias"
#   f: 0.0
#   type: FLOAT
# }
# domain: "qonnx.custom_op.general"

# %%
for node in Multithreshold_node:
    node_inst = getCustomOp(node)
    if node_inst.get_nodeattr("out_dtype") == "BIPOLAR":
        node_inst.set_nodeattr("out_dtype", "BINARY")
        node_inst.set_nodeattr("out_scale", 1.0)
        node_inst.set_nodeattr("out_bias", 0.0)
        print(node)
# Out:
# input: "MatMul_18_out0"
# input: "MultiThreshold_19_param0"
# output: "global_out"
# name: "MultiThreshold_19"
# op_type: "MultiThreshold"
# attribute {
#   name: "out_dtype"
#   s: "BINARY"
#   type: STRING
# }
# attribute {
#   name: "out_scale"
#   f: 1.0
#   type: FLOAT
# }
# attribute {
#   name: "out_bias"
#   f: 0.0
#   type: FLOAT
# }
# domain: "qonnx.custom_op.general"

# %%
global_out_name = model.graph.output[0].name
global_out_name
# Out:
# 'global_out'

# %%
model.set_tensor_datatype(global_out_name, DataType["BINARY"])

# %%
finn_bipolar_to_binary = models_folder + '06_finn_bipolar_to_binary.onnx'

# %%
model.save(finn_bipolar_to_binary)

# %%
showInNetron(finn_bipolar_to_binary)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/06_finn_bipolar_to_binary.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Standlone Thresholds

# %%
model = ModelWrapper(finn_bipolar_to_binary)

model = model.transform(to_hw.InferThresholdingLayer())

# %%
finn_std_alone_thres = models_folder + '07_finn_std_alone_thres.onnx'

# %%
model.save(finn_std_alone_thres)

# %%
showInNetron(finn_std_alone_thres)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/07_finn_std_alone_thres.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Rest of the Streamline Process

# %%
model = ModelWrapper(finn_std_alone_thres)
model = model.transform(to_hw.InferQuantizedMatrixVectorActivation())

# input quantization (if any) to standalone thresholding
model = model.transform(to_hw.InferThresholdingLayer())
model = model.transform(to_hw.InferPool())
model = model.transform(to_hw.InferStreamingMaxPool())
model = model.transform(to_hw.InferConvInpGen())

# get rid of Reshape(-1, 1) operation between hw nodes 
model = model.transform(RemoveCNVtoFCFlatten())

# get rid of Tranpose -> Tranpose identity seq
model = model.transform(absorb.AbsorbConsecutiveTransposes())

# infer tensor data layouts
model = model.transform(InferDataLayouts())

model = model.transform(Streamline())

# %%
finn_hw_layers = models_folder + '08_fin_hw_layers.onnx'
model.save(finn_hw_layers)

# %%
showInNetron(finn_hw_layers)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/08_fin_hw_layers.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Dataflow Partition

# %%
model = ModelWrapper(finn_hw_layers)
parent_model = model.transform(CreateDataflowPartition())

# %%
finn_parent_filename = models_folder + '00_finn_dataflow_parent.onnx'
parent_model.save(finn_parent_filename)

# %%
showInNetron(finn_parent_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/00_finn_dataflow_parent.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
sdp_node = parent_model.get_nodes_by_op_type("StreamingDataflowPartition")[0]
sdp_node = getCustomOp(sdp_node)
dataflow_filename = sdp_node.get_nodeattr("model")
dataflow_model = ModelWrapper(dataflow_filename)

# %% [markdown]
# # Specialize Layers

# %%
from finn.transformation.fpgadataflow.specialize_layers import SpecializeLayers

# %% [markdown]
# ### There are no Padding Nodes in Balanced Model (Aimet No Padding Balanced)

# %%
FMPadding_node = dataflow_model.get_nodes_by_op_type("FMPadding")
i = 0
for node in FMPadding_node:
    node_inst = getCustomOp(node)
    node_inst.set_nodeattr("preferred_impl_style", "hls")
    print(f'Node {i}: {node}')
    i += 1

# %%
# save the dataflow partition with a different name for easier access
# and specialize the layers to HLS variants
dataflow_model = dataflow_model.transform(SpecializeLayers(fpga_part))

dataflow_model = dataflow_model.transform(GiveUniqueNodeNames())
dataflow_model = dataflow_model.transform(GiveReadableTensorNames())

finn_dataflow_filename = models_folder + '20_finn_dataflow_model.onnx'
dataflow_model.save(finn_dataflow_filename)

# %%
showInNetron(finn_dataflow_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving './models/aimet_balanced/20_finn_dataflow_model.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Check execution???

# %%
# parent_dataflow_model = ModelWrapper(finn_parent_filename)

# %%
# input_dict = {"global_in": test_ip*255}
# output_dict = oxe.execute_onnx(parent_dataflow_model, input_dict)
# produced_clean_qonnx = output_dict[list(output_dict.keys())[0]]
# produced_clean_qonnx

# %% [markdown]
# # Folding Factors

# %%
from finn.transformation.fpgadataflow.set_folding import SetFolding

# %% [markdown]
# **Taregt Cycles Per Frame**
#
# If target is 25 FPS, inference time is $\frac{1}{25}=40ms$
#
# If $clk = 10 ns$:
# $$
# Target~Cycles~Per~Frame = \frac{40\times 10^{-3}}{10\times 10^{-9}}= 4\times 10^{6}
# $$
#
# No se tiene en cuenta el tiempo de preprocesado, que en realidad debería ser inexistente, ya que está embebido en el preprocess del modelo.

# %%
# folder = SetFolding(
#     target_cycles_per_frame=4000000,#1000,
#     mvau_wwidth_max=36,
#     two_pass_relaxation=True
# )

# %%
model = ModelWrapper(finn_dataflow_filename)

# %% [markdown]
# apply method of SetFolding returns (model, False), so model is [0]
#
# maybe it is easier to do: model, _ = folder.apply(...)

# %%
# model = folder.apply(model)

model = model.transform(SetFolding(
    target_cycles_per_frame=4000000,#1000,
    mvau_wwidth_max=36,
    two_pass_relaxation=True)
)

# %%
folding_filename = models_folder + '30_finn_folding.onnx'
#model[0].save(folding_filename)
model.save(folding_filename)

# %%
showInNetron(folding_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving 'experiments/01_w2a2/models/30_finn_folding.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Check Total Estimated Cycles, looping over each node attribute

# %%
all_nodes = model.get_finn_nodes()

# %%
i = 0
total_cycles = []
for node in all_nodes:
    my_node = getCustomOp(node)
    node_cycles = my_node.get_nodeattr("cycles_estimate")
    total_cycles.append(node_cycles)
    print(f'Node {i} estimated cycles: {node_cycles}')
    i += 1
print(f'\nTotal estimated cycles: {np.array(total_cycles).sum()}')
# Out:
# Node 0 estimated cycles: 150528
# Node 1 estimated cycles: 153228
# Node 2 estimated cycles: 1356117
# Node 3 estimated cycles: 1605632
# Node 4 estimated cycles: 2008896
# Node 5 estimated cycles: 1605632
# Node 6 estimated cycles: 415872
# Node 7 estimated cycles: 3620064
# Node 8 estimated cycles: 3612672
# Node 9 estimated cycles: 251360
# Node 10 estimated cycles: 200704
# Node 11 estimated cycles: 802816
# Node 12 estimated cycles: 53824
# Node 13 estimated cycles: 453488
# Node 14 estimated cycles: 3612672
# Node 15 estimated cycles: 3211264
# Node 16 estimated cycles: 107648
# Node 17 estimated cycles: 906976
# Node 18 estimated cycles: 3612672
# Node 19 estimated cycles: 257392
# Node 20 estimated cycles: 200704
# Node 21 estimated cycles: 1605632
# Node 22 estimated cycles: 28800
# Node 23 estimated cycles: 227808
# Node 24 estimated cycles: 3612672
# Node 25 estimated cycles: 1605632
# Node 26 estimated cycles: 28800
# Node 27 estimated cycles: 227808
# Node 28 estimated cycles: 3612672
# Node 29 estimated cycles: 1605632
# Node 30 estimated cycles: 28800
# Node 31 estimated cycles: 227808
# Node 32 estimated cycles: 3612672
# Node 33 estimated cycles: 150437
# Node 34 estimated cycles: 50176
# Node 35 estimated cycles: 1024
# Node 36 estimated cycles: 32
#
# Total estimated cycles: 44826566

# %% [markdown]
# # Minimize

# %%
from finn.transformation.fpgadataflow.minimize_accumulator_width import (
    MinimizeAccumulatorWidth,
)
from finn.transformation.fpgadataflow.minimize_weight_bit_width import (
    MinimizeWeightBitWidth,
)

# %%
model = ModelWrapper(folding_filename)

# %%
model = model.transform(MinimizeAccumulatorWidth())
model = model.transform(MinimizeWeightBitWidth())

# %%
minimize_filename = models_folder + '31_finn_minimize.onnx'
model.save(minimize_filename)

# %%
showInNetron(minimize_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving 'experiments/01_w2a2/models/31_finn_minimize.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # HW IP Generation: PrepareIP and HLSSynthIP

# %%
# from finn.transformation.fpgadataflow.prepare_ip import PrepareIP
# from finn.transformation.fpgadataflow.hlssynth_ip import HLSSynthIP

# %%
# model = ModelWrapper(minimize_filename)

# %%
# model = model.transform(PrepareIP(fpga_part, target_clk_ns))
# model = model.transform(HLSSynthIP())

# %%
# hw_filename = models_folder + '32_finn_hw_ipgen.onnx'
# model.save(hw_filename)

# %%
# showInNetron(hw_filename)

# %% [markdown]
# # FIFO depths

# %%
from finn.transformation.fpgadataflow.set_fifo_depths import InsertAndSetFIFODepths

# %%
# Default settings
# fifo_depths = InsertAndSetFIFODepths(
#     fpgapart=fpga_part,
#     clk_ns=10.0,
#     max_qsrl_depth=256,
#     max_depth=None,
#     swg_exception=False,#True, # Used to optimize convolution FIFOs, splitting in several with Power of Two
#     vivado_ram_style="auto",
#     force_python_sim=False,
# )

# %%
#model = ModelWrapper(hw_filename)

model = ModelWrapper(minimize_filename)

# %%
#model = fifo_depths.apply(model)

model = model.transform(InsertAndSetFIFODepths(
    fpgapart=fpga_part,
    clk_ns=10.0,
    max_qsrl_depth=256,
    max_depth=None,
    swg_exception=False,#True, # Used to optimize convolution FIFOs, splitting in several with Power of Two
    vivado_ram_style="auto",
    force_python_sim=False)
)
# Out:
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23168:8: Duplicate declaration of module: 'dwc_axi'
# 23168 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
#                  ... For warning description see https://verilator.org/warn/MODDUP?v=4.224
#                  ... Use "/* verilator lint_off MODDUP */" and lint_on around source to disable this message.
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:25289:8: Duplicate declaration of module: 'swg_controller'
# 25289 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:25404:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 25404 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:25431:8: Duplicate declaration of module: 'swg_reg_buffer'
# 25431 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:25460:8: Duplicate declaration of module: 'swg_ram_buffer'
# 25460 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:28416:8: Duplicate declaration of module: 'swg_controller'
# 28416 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:28531:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 28531 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:28558:8: Duplicate declaration of module: 'swg_reg_buffer'
# 28558 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:28587:8: Duplicate declaration of module: 'swg_ram_buffer'
# 28587 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:28918:8: Duplicate declaration of module: 'swg_controller'
# 28918 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29033:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 29033 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29060:8: Duplicate declaration of module: 'swg_reg_buffer'
# 29060 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29089:8: Duplicate declaration of module: 'swg_ram_buffer'
# 29089 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29661:8: Duplicate declaration of module: 'swg_controller'
# 29661 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29776:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 29776 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29803:8: Duplicate declaration of module: 'swg_reg_buffer'
# 29803 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:29832:8: Duplicate declaration of module: 'swg_ram_buffer'
# 29832 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:35631:8: Duplicate declaration of module: 'dwc'
# 35631 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:45910:8: Duplicate declaration of module: 'swg_controller'
# 45910 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:46025:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 46025 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:46052:8: Duplicate declaration of module: 'swg_reg_buffer'
# 46052 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:46081:8: Duplicate declaration of module: 'swg_ram_buffer'
# 46081 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:51674:8: Duplicate declaration of module: 'swg_controller'
# 51674 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:51789:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 51789 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:51816:8: Duplicate declaration of module: 'swg_reg_buffer'
# 51816 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:51845:8: Duplicate declaration of module: 'swg_ram_buffer'
# 51845 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:62335:8: Duplicate declaration of module: 'dwc_axi'
# 62335 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:67042:8: Duplicate declaration of module: 'dwc_axi'
# 67042 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:67110:8: Duplicate declaration of module: 'dwc'
# 67110 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:67842:8: Duplicate declaration of module: 'dwc_axi'
# 67842 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71012:8: Duplicate declaration of module: 'swg_controller'
# 71012 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71127:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 71127 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71154:8: Duplicate declaration of module: 'swg_reg_buffer'
# 71154 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71183:8: Duplicate declaration of module: 'swg_ram_buffer'
# 71183 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71815:8: Duplicate declaration of module: 'swg_controller'
# 71815 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71930:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 71930 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71957:8: Duplicate declaration of module: 'swg_reg_buffer'
# 71957 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:71986:8: Duplicate declaration of module: 'swg_ram_buffer'
# 71986 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:72475:8: Duplicate declaration of module: 'dwc'
# 72475 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:72884:8: Duplicate declaration of module: 'dwc'
# 72884 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:75866:8: Duplicate declaration of module: 'swg_controller'
# 75866 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:75981:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 75981 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:76008:8: Duplicate declaration of module: 'swg_reg_buffer'
# 76008 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:76037:8: Duplicate declaration of module: 'swg_ram_buffer'
# 76037 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:78170:8: Duplicate declaration of module: 'dwc_axi'
# 78170 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:80329:8: Duplicate declaration of module: 'axi4lite_if'
# 80329 | module axi4lite_if
#       |        ^~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:10529:8: ... Location of original declaration
# 10529 | module axi4lite_if
#       |        ^~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:80545:8: Duplicate declaration of module: 'dwc_axi'
# 80545 | module dwc_axi #(
#       |        ^~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:23100:8: ... Location of original declaration
# 23100 | module dwc_axi #(
#       |        ^~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:90001:8: Duplicate declaration of module: 'dwc'
# 90001 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:91672:8: Duplicate declaration of module: 'swg_controller'
# 91672 | module swg_controller
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:1979:8: ... Location of original declaration
#  1979 | module swg_controller
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:91787:8: Duplicate declaration of module: 'swg_cyclic_buffer_addressable'
# 91787 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2094:8: ... Location of original declaration
#  2094 | module swg_cyclic_buffer_addressable #(
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:91814:8: Duplicate declaration of module: 'swg_reg_buffer'
# 91814 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2121:8: ... Location of original declaration
#  2121 | module swg_reg_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:91843:8: Duplicate declaration of module: 'swg_ram_buffer'
# 91843 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:2150:8: ... Location of original declaration
#  2150 | module swg_ram_buffer
#       |        ^~~~~~~~~~~~~~
# %Warning-MODDUP: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:92944:8: Duplicate declaration of module: 'dwc'
# 92944 | module dwc #(
#       |        ^~~
#                  /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:19852:8: ... Location of original declaration
# 19852 | module dwc #(
#       |        ^~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'awready'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'wready'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'bvalid'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'bresp'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'arready'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'rvalid'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'rresp'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17296:34: Cell has missing pin: 'rdata'
# 17296 |   finn_design_MVAU_hls_0_wstrm_0 MVAU_hls_0_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'awready'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'wready'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'bvalid'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'bresp'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'arready'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'rvalid'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'rresp'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17365:35: Cell has missing pin: 'rdata'
# 17365 |   finn_design_MVAU_hls_10_wstrm_0 MVAU_hls_10_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'awready'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'wready'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'bvalid'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'bresp'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'arready'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'rvalid'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'rresp'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17434:35: Cell has missing pin: 'rdata'
# 17434 |   finn_design_MVAU_hls_11_wstrm_0 MVAU_hls_11_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'awready'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'wready'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'bvalid'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'bresp'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'arready'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'rvalid'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'rresp'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17503:35: Cell has missing pin: 'rdata'
# 17503 |   finn_design_MVAU_hls_12_wstrm_0 MVAU_hls_12_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'awready'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'wready'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'bvalid'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'bresp'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'arready'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'rvalid'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'rresp'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17572:35: Cell has missing pin: 'rdata'
# 17572 |   finn_design_MVAU_hls_13_wstrm_0 MVAU_hls_13_wstrm
#       |                                   ^~~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'awready'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'wready'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'bvalid'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'bresp'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'arready'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'rvalid'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'rresp'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17641:34: Cell has missing pin: 'rdata'
# 17641 |   finn_design_MVAU_hls_1_wstrm_0 MVAU_hls_1_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'awready'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'wready'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'bvalid'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'bresp'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'arready'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'rvalid'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'rresp'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17710:34: Cell has missing pin: 'rdata'
# 17710 |   finn_design_MVAU_hls_2_wstrm_0 MVAU_hls_2_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'awready'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'wready'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'bvalid'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'bresp'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'arready'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'rvalid'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'rresp'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17779:34: Cell has missing pin: 'rdata'
# 17779 |   finn_design_MVAU_hls_3_wstrm_0 MVAU_hls_3_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'awready'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'wready'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'bvalid'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'bresp'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'arready'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'rvalid'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'rresp'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17848:34: Cell has missing pin: 'rdata'
# 17848 |   finn_design_MVAU_hls_4_wstrm_0 MVAU_hls_4_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'awready'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'wready'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'bvalid'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'bresp'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'arready'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'rvalid'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'rresp'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17917:34: Cell has missing pin: 'rdata'
# 17917 |   finn_design_MVAU_hls_5_wstrm_0 MVAU_hls_5_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'awready'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'wready'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'bvalid'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'bresp'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'arready'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'rvalid'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'rresp'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:17986:34: Cell has missing pin: 'rdata'
# 17986 |   finn_design_MVAU_hls_6_wstrm_0 MVAU_hls_6_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'awready'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'wready'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'bvalid'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'bresp'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'arready'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'rvalid'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'rresp'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18055:34: Cell has missing pin: 'rdata'
# 18055 |   finn_design_MVAU_hls_7_wstrm_0 MVAU_hls_7_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'awready'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'wready'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'bvalid'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'bresp'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'arready'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# %Warning-PINMISSING: /home/gmoreno/workspace/vivado_stitch_proj_7yak8qkc/finn_design_wrapper.v:18124:34: Cell has missing pin: 'rvalid'
# 18124 |   finn_design_MVAU_hls_8_wstrm_0 MVAU_hls_8_wstrm
#       |                                  ^~~~~~~~~~~~~~~~
# ...
# Elapsed since last report = 0[s]
# Elapsed iters 7735000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7736000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7737000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7738000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7739000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7740000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7741000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7742000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7743000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7744000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7745000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7746000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7747000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7748000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7749000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7750000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7751000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7752000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7753000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7754000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7755000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7756000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7757000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7758000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7759000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7760000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7761000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7762000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7763000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7764000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7765000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7766000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7767000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7768000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7769000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7770000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7771000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7772000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7773000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7774000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7775000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7776000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7777000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7778000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7779000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7780000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7781000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7782000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7783000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7784000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7785000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7786000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7787000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7788000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7789000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7790000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7791000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7792000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7793000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7794000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7795000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7796000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7797000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7798000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7799000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7800000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7801000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7802000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7803000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7804000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7805000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7806000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7807000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7808000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7809000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7810000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7811000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7812000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7813000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7814000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7815000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7816000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7817000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7818000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7819000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7820000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7821000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7822000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7823000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7824000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7825000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7826000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7827000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7828000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7829000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7830000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7831000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7832000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7833000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7834000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7835000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7836000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7837000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7838000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7839000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7840000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7841000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7842000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7843000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7844000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7845000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7846000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7847000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7848000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7849000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7850000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7851000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7852000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7853000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7854000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7855000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7856000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7857000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7858000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7859000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7860000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7861000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7862000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7863000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7864000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7865000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7866000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7867000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7868000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7869000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7870000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7871000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7872000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7873000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7874000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7875000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7876000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7877000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7878000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7879000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7880000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7881000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7882000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7883000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7884000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7885000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7886000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7887000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7888000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7889000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7890000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7891000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7892000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7893000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7894000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7895000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7896000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7897000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7898000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7899000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7900000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7901000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7902000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7903000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7904000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7905000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7906000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7907000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7908000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7909000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7910000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7911000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7912000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7913000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7914000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7915000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7916000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7917000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7918000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7919000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7920000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7921000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7922000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7923000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7924000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7925000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7926000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7927000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7928000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7929000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7930000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7931000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7932000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7933000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7934000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7935000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7936000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7937000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7938000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7939000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7940000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7941000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7942000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7943000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7944000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7945000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7946000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7947000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Elapsed iters 7948000 inps 301056 outs 2
# Elapsed since last report = 0[s]
# Simulation finished
# Number of inputs consumed 301056
# Number of outputs produced 4
# Number of clock cycles 7948020

# %%
fifo_filename = models_folder + '31_finn_fifo.onnx'
#model[0].save(fifo_filename)
model.save(fifo_filename)

# %%
showInNetron(fifo_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving 'experiments/01_w2a2/models/31_finn_fifo.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Streamline FIFOs

# %%
from finn.transformation.fpgadataflow.set_fifo_depths import SplitLargeFIFOs
from finn.transformation.fpgadataflow.set_fifo_depths import RemoveShallowFIFOs

# %%
#model = model[0].transform(SplitLargeFIFOs())

model = model.transform(SplitLargeFIFOs())
model = model.transform(RemoveShallowFIFOs())
# Out:
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_1: rounding-up FIFO depth from 116540 to 131072 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_2: rounding-up FIFO depth from 153228 to 262144 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_4: rounding-up FIFO depth from 15637 to 16384 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_5: rounding-up FIFO depth from 34469 to 65536 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_7: rounding-up FIFO depth from 38684 to 65536 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_8: rounding-up FIFO depth from 415872 to 524288 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_15: rounding-up FIFO depth from 1618 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_17: rounding-up FIFO depth from 2786 to 4096 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_20: rounding-up FIFO depth from 3234 to 4096 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_22: rounding-up FIFO depth from 778 to 1024 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_27: rounding-up FIFO depth from 1664 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_29: rounding-up FIFO depth from 2974 to 4096 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_32: rounding-up FIFO depth from 1664 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_34: rounding-up FIFO depth from 2038 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_37: rounding-up FIFO depth from 1664 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_39: rounding-up FIFO depth from 2038 to 2048 for impl_style=vivado
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/custom_op/fpgadataflow/rtl/streamingfifo_rtl.py:70: UserWarning: StreamingFIFO_rtl_40: rounding-up FIFO depth from 524 to 1024 for impl_style=vivado
#   warnings.warn(

# %%
# after FIFOs are ready to go, call PrepareIP and HLSSynthIP again
# this will only run for the new nodes (e.g. FIFOs and DWCs) -> DWCs for Mobilenet
# model = model.transform(PrepareIP(fpga_part, target_clk_ns))
# model = model.transform(HLSSynthIP())

# %%
fifo_streamline_filename = models_folder + '33_finn_fifo_streamline.onnx'
model.save(fifo_streamline_filename)

# %%
showInNetron(fifo_streamline_filename)
# Out:
# Stopping http://0.0.0.0:8083
# Serving 'experiments/01_w2a2/models/33_finn_fifo_streamline.onnx' at http://0.0.0.0:8083
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # PYNQ Driver

# %%
from finn.transformation.fpgadataflow.make_zynq_proj import ZynqBuild

# %%
model = ModelWrapper(fifo_streamline_filename)
model = model.transform(ZynqBuild(platform = pynq_board, period_ns = target_clk_ns))
# Out:
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/floorplan.py:107: UserWarning: 158 nodes have no entry in the provided floorplan, SLR was set to -1
#   warnings.warn(
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_Thresholding_rtl_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_Pool_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_Pool_hls_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_4
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_4
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_5
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_5
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_6
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_Pool_hls_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_6
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_4
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_7
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_4
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_7
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_8
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_5
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_8
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_5
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_9
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_10
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_FMPadding_hls_6
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_9
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_StreamingDataWidthConverter_rtl_6
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_11
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_ConvolutionInputGenerator_rtl_10
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_Pool_hls_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_12
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for StreamingDataflowPartition_1_MVAU_hls_13
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_13
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_12
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_Pool_hls_3
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_11
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_6
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_10
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_9
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_5
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_8
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_7
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_4
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_6
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_Pool_hls_2
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_5
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_3
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_4
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_3
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_2
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_2
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_Pool_hls_1
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_1
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_1
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_Pool_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_MVAU_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for StreamingDataflowPartition_1_FMPadding_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# ERROR: [Common 17-69] Command failed: Run 'impl_1' failed. Unable to open
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 model = ModelWrapper(fifo_streamline_filename)
# ----> 2 model = model.transform(ZynqBuild(platform = pynq_board, period_ns = target_clk_ns))
#
# File /home/gmoreno/uav/finn/deps/qonnx/src/qonnx/core/modelwrapper.py:140, in ModelWrapper.transform(self, transformation, make_deepcopy, cleanup)
#     138 model_was_changed = True
#     139 while model_was_changed:
# --> 140     (transformed_model, model_was_changed) = transformation.apply(transformed_model)
#     141 if cleanup:
#     142     transformed_model.cleanup()
#
# File /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/make_zynq_proj.py:352, in ZynqBuild.apply(self, model)
#     350     kernel_model.save(dataflow_model_filename)
#     351 # Assemble design from IPs
# --> 352 model = model.transform(MakeZYNQProject(self.platform, enable_debug=self.enable_debug))
#     354 # set platform attribute for correct remote execution
#     355 model.set_metadata_prop("platform", "zynq-iodma")
#
# File /home/gmoreno/uav/finn/deps/qonnx/src/qonnx/core/modelwrapper.py:140, in ModelWrapper.transform(self, transformation, make_deepcopy, cleanup)
#     138 model_was_changed = True
#     139 while model_was_changed:
# --> 140     (transformed_model, model_was_changed) = transformation.apply(transformed_model)
#     141 if cleanup:
#     142     transformed_model.cleanup()
#
# File /home/gmoreno/uav/finn/src/finn/transformation/fpgadataflow/make_zynq_proj.py:269, in MakeZYNQProject.apply(self, model)
#     267 bitfile_name = vivado_pynq_proj_dir + "/finn_zynq_link.runs/impl_1/top_wrapper.bit"
#     268 if not os.path.isfile(bitfile_name):
# --> 269     raise Exception(
#     270         "Synthesis failed, no bitfile found. Check logs under %s" % vivado_pynq_proj_dir
#     271     )
#     272 deploy_bitfile_name = vivado_pynq_proj_dir + "/resizer.bit"
#     273 copy(bitfile_name, deploy_bitfile_name)
#
# Exception: Synthesis failed, no bitfile found. Check logs under /home/gmoreno/workspace/vivado_zynq_proj_bumup3lp

# %%
from finn.transformation.fpgadataflow.make_pynq_driver import MakePYNQDriver

# %%
model = model.transform(MakePYNQDriver("zynq-iodma"))

# %%
pynq_driver_filename = '40_pynq_driver.onnx'
model.save(pynq_driver_filename)
