# %%
import os
import logging
from pathlib import Path
import datetime

from tqdm import tqdm
import numpy as np
import math
import random

import onnx
import onnxscript
import onnxruntime

import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from torchvision.models import shufflenet_v2_x0_5

import albumentations as A
from albumentations.pytorch import ToTensorV2

import matplotlib.pyplot as plt

import torch.nn as nn 
from torch.nn.utils import parameters_to_vector

import torchmetrics

import cv2
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.13 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations

# %%
#torch.cuda.empty_cache()

# %% [markdown]
# # Logger

# %%
log_path = 'results_onnx/'

logger = logging.getLogger("GonLogger")
logger.propagate = False
logger.setLevel(logging.INFO)
file_handler = logging.FileHandler(log_path + 'logfile.log')
formatter = logging.Formatter('%(message)s')
file_handler.setFormatter(formatter)

# add file handler to logger
logger.addHandler(file_handler)

logger.info('ShuffleNet Classifier. Onnx export.')

# %% [markdown]
# # Config

# %%
CLASSES = ["smoke", "fire"]
N_CLASSES = len(CLASSES)

IMG_DIM = {'W':224, 'H':224} # (W, H)
IMG_H = IMG_DIM['H']
IMG_W = IMG_DIM['W']

# %% [markdown]
# # Hyperparameters

# %%
''' ============================
    Hyperparameters and More
============================ '''

MODEL = "SHUFFLE"
PRETRAINED = True

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 64 
NUM_WORKERS = 8
PIN_MEMORY = True

ds_dir = '../../../datasets/ds2fire/dfire_yolo/'
val_dir = ds_dir + 'test/'
VAL_IMG_DIR = val_dir + 'images/'
VAL_LABEL_DIR = val_dir + 'labels/'

# %% [markdown]
# # Dataset DFire

# %%
class DFireDataset(Dataset):
    '''
    Creates a Pytorch Dataset to train the Yolov1 Network.
    Encodes labels to match the format [xcell, ycell, w, h, confidence, class_0 (smoke), class_1 (fire)]
        - Final encoding format is: [xcell, ycell, w, h, conf=1, smoke?, fire?]

    Discard images when there are more than 1 object in the same cell
    
    Arguments:
        - img_h:            image height
        - img_w:            image width
        - img_dir:          path to images folder
        - label_dir:        path to labels folder
        - num_classes:      number of classes
        - transform:        transformation applied to input images -> Albumentations
        - target_transform: transformation applied to labels -> nothing by default

    Return:
        - img:              1 image of the dataset
        - target:           corresponding label encoded: [smoke, fire]
    '''

    def __init__(self, img_h, img_w, img_dir, label_dir, num_classes,
                 ds_len,
                 transform=None, target_transform=None):
        self.img_h = img_h
        self.img_w = img_w
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.num_classes = num_classes
        self.ds_len = ds_len
        self.transform = transform
        self.target_transform = target_transform
        
        self.except_transform = A.Compose([
                                    A.Resize(self.img_h, self.img_w, p=1),
                                    ToTensorV2(p=1),
                                    ]
                                )

        self.labels_list = sorted(
            [
                os.path.join(self.label_dir, file_name)
                for file_name in os.listdir(self.label_dir)
                if file_name.endswith(".txt")
            ]
        )
    
        if ds_len is not None:
            random.seed(123)
            random.shuffle(self.labels_list)
            self.images_path, self.labels = self.__build_ds__(self.labels_list[:self.ds_len])
            self.num_samples = len(self.labels_list[:self.ds_len])
        else:
            self.images_path, self.labels = self.__build_ds__(self.labels_list)
            self.num_samples = len(self.labels_list)

    def __len__(self):
        return self.num_samples   

    def __build_ds__(self, labels_list):
        labels = []
        images = []
        wrong_imgs = 0
        empty = 0
        only_smoke = 0
        only_fire = 0
        smoke_fire = 0
                
        for label in labels_list:
            fname = Path(label).stem
            image_path = self.img_dir + fname + '.jpg'   
            #print(fname, image_path)
                                   
            if cv2.imread(image_path) is None:
                print(f'{image_path} cannot be read by cv2 -> removed')
                wrong_imgs += 1
            
            else:
                
                label_array = np.zeros((self.num_classes))
            
                with open(label) as f:
                    lines = f.readlines()
                       
                    for line in lines:
                        class_id, _, _, _, _ = line.strip().split()
                        class_id = int(class_id)
                        if np.array_equal(label_array, np.array([1, 1])):
                            break
                        else:
                            label_array[class_id] = 1.

                    if np.array_equal(label_array, np.array([1, 1])):
                        smoke_fire += 1
                    elif np.array_equal(label_array, np.array([0, 1])):
                        only_fire += 1
                    elif np.array_equal(label_array, np.array([1, 0])):
                        only_smoke += 1
                    elif np.array_equal(label_array, np.array([0, 0])):
                        empty += 1
                    else:
                        print("Wrong label in DFire dataset")
                        logger.info("Wrong label in DFire dataset")
                        
                    labels.append(label_array)
                    images.append(image_path)
        
        print(f'DFire Removed wrong images: {wrong_imgs}')
        logger.info(f'DFire Removed wrong images: {wrong_imgs}')
        print(f'DFire empty images: {empty}')
        logger.info(f'DFire empty images: {empty}')
        print(f'DFire only smoke images: {only_smoke}')
        logger.info(f'DFire only smoke images: {only_smoke}')
        print(f'DFire only fire images: {only_fire}')
        logger.info(f'DFire only fire images: {only_fire}')
        print(f'DFire smoke and fire images: {smoke_fire}')
        logger.info(f'DFire smoke and fire images: {smoke_fire}')

        labels_np = np.array(labels)
        labels_tensor = torch.tensor(labels_np, dtype=torch.float32)
        images_array = np.array(images)
        
        return images_array, labels_tensor

    def __getitem__(self, index):

        # Image processing
        img_file = self.images_path[index]
        img = cv2.imread(img_file)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   

        # Labels processing
        label = self.labels[index]
        
        # Data Augmentation
        if self.transform is not None:
            try:
                aug = self.transform(image=img)
                img = aug['image'] / 255.0
            except:
                #print(f'Error trying to augment image {img_file}')
                aug = self.except_transform(image=img)
                img = aug['image'] / 255.0
        
        return img, label

# %% [markdown]
# ## Dataset Setup

# %%
# VALIDATION DATASET
val_transform = A.Compose([
    A.Resize(IMG_H, IMG_W, p=1),
    ToTensorV2(p=1),
    ]
)

print("\nTEST DFire dataset")
logger.info("\nTEST DFire dataset")
val_dataset = DFireDataset(img_h = IMG_H,
                           img_w = IMG_W,
                           img_dir = VAL_IMG_DIR,
                           label_dir = VAL_LABEL_DIR,
                           num_classes = N_CLASSES,
                           ds_len = None,
                           transform=val_transform)

print(f'Test dataset len: {len(val_dataset)}')
logger.info(f'Test dataset len: {len(val_dataset)}')


# LOADERS
val_loader = DataLoader(dataset=val_dataset,
                        batch_size=BATCH_SIZE,
                        num_workers=NUM_WORKERS,
                        pin_memory=PIN_MEMORY,
                        shuffle=False,
                        drop_last=True)
# Out:
# TEST DFire dataset
# DFire Removed wrong images: 0
# DFire empty images: 2005
# DFire only smoke images: 1186
# DFire only fire images: 220
# DFire smoke and fire images: 895
# Test dataset len: 4306

# %% [markdown]
# # Pytorch Model

# %% [markdown]
# ## ShuffleNet Pretrained

# %%
class PRETRAINED_SHUFFLE(nn.Module):
    def __init__(self, base_model, last_channels, num_classes, in_channels=3):
        super().__init__()
        self.in_channels = in_channels
        self.num_classes = num_classes
        self.last_channels = last_channels
        
        self.base_model = nn.Sequential(*list(base_model.children())[:-1])

        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.smoke = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=self.last_channels, out_features=16),
            nn.ReLU(),
            nn.Linear(in_features=16, out_features=1)
        )
        self.fire = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=self.last_channels, out_features=16),
            nn.ReLU(),
            nn.Linear(in_features=16, out_features=1)
        )

    
    def forward(self, x):
        x = self.base_model(x)
        x = self.pool(x)
        x = torch.flatten(x, start_dim=1)
        x = torch.cat((self.smoke(x), self.fire(x)), dim=-1)
        #x = torch.sigmoid(x) # BCE Logits
        return x

# %% [markdown]
# ## Model Setup

# %%
''' ======================================
    SETUP: Model, Loss, Dataset, Loader
====================================== '''

def setup_model(pretrained, model_name):
    if pretrained == True:
        if model_name == "SHUFFLE":
            print("Using SHUFFLE Classifier")
            logger.info("Using SHUFFLE Classifier")
        
            base_model = shufflenet_v2_x0_5(weights='IMAGENET1K_V1')
            print(list(base_model.children())[-1])
            for name, layer in base_model.named_modules():
                if isinstance(layer, nn.Linear):
                    last_channels = layer.in_features
                    print(f'Model Pretrained has {last_channels} in features in last layer')
                    logger.info(f'Model Pretrained has {last_channels} in features in last layer')
            # for param in base_model.parameters():
            #     param.requires_grad = False
            
            model = PRETRAINED_SHUFFLE(base_model, last_channels, num_classes=N_CLASSES).to(DEVICE)   

            return model
    else:
        print("Wrong Model")
        logger.info("Wrong Model")
        raise SystemExit("Wrong Model")
        
model = setup_model(pretrained=PRETRAINED, model_name=MODEL)

# Check model shape
in_rand_np = np.random.rand(4, 3, IMG_H, IMG_W)
in_rand = torch.tensor(in_rand_np, dtype=torch.float32, device=DEVICE)
out_test = model(in_rand)
print(f'Model shape is {out_test}')
print(f'BED Model Arquitecture\n{model}')
logger.info(f'Model shape is {out_test}')
logger.info(f'BED Model Arquitecture\n{model}')

# MODEL PARAMETERS
n_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'\nTrainable parameters = {n_trainable}')
logger.info(f'\nTrainable parameters = {n_trainable}')

n_params = parameters_to_vector(model.parameters()).numel()
print(f'Total parameters = {n_params}\n')
logger.info(f'Total parameters = {n_params}\n')
# Out:
# Using SHUFFLE Classifier
# Linear(in_features=1024, out_features=1000, bias=True)
# Model Pretrained has 1024 in features in last layer
# Model shape is tensor([[-0.1862,  0.1325],
#         [-0.1771,  0.1324],
#         [-0.1880,  0.1309],
#         [-0.1814,  0.1389]], device='cuda:0', grad_fn=<CatBackward0>)
# BED Model Arquitecture
# PRETRAINED_SHUFFLE(
#   (base_model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (4): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (5): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (6): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (7): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): Conv2d(192, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (smoke): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1024, out_features=16, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=16, out_features=1, bias=True)
#   )
#   (fire): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1024, out_features=16, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
#
# Trainable parameters = 374626
# Total parameters = 374626

# %% [markdown]
# ## Load Checkpoint

# %%
def load_checkpoint(model_path, model, optimizer, scheduler, device):
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    if scheduler is not None:
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    start_epoch = checkpoint['epoch']
    print(f"Loading Model. Trained during {start_epoch} epochs")
    return start_epoch

# %%
model_path = './results_v1/SHUFFLE_FineTune_best_classifier.pt'
load_checkpoint(
    model_path,
    model,
    None,
    None,
    DEVICE)
# Out:
# Loading Model. Trained during 158 epochs
# 158

# %%
model.eval()
# Out:
# PRETRAINED_SHUFFLE(
#   (base_model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#           (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (4): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (5): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (6): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (7): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (branch1): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU(inplace=True)
#         )
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (1): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (2): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#       (3): InvertedResidual(
#         (branch1): Sequential()
#         (branch2): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): ReLU(inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): Conv2d(192, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (smoke): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1024, out_features=16, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=16, out_features=1, bias=True)
#   )
#   (fire): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1024, out_features=16, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Metrics

# %%
precision_metric = torchmetrics.classification.MultilabelPrecision(num_labels = N_CLASSES, 
                                                                   threshold = 0.5, 
                                                                   average = None).to(DEVICE)
recall_metric = torchmetrics.classification.MultilabelRecall(num_labels = N_CLASSES, 
                                                             threshold = 0.5, 
                                                             average = None).to(DEVICE)
accuracy_metric = torchmetrics.classification.MultilabelAccuracy(num_labels = N_CLASSES, 
                                                                 threshold = 0.5, 
                                                                 average = None).to(DEVICE)
f1_metric = torchmetrics.classification.MultilabelF1Score(num_labels = N_CLASSES, 
                                                          threshold = 0.5, 
                                                          average = None).to(DEVICE)

# %% [markdown]
# ## Validation Loop

# %%
'''
Evaluation Function
'''
def eval_fn(loader, model, device):
    
    model.eval()
    loop = tqdm(loader, desc='Validating', leave=True)

    for batch_idx, (x, y) in enumerate(loop):
        x, y = x.to(device), y.to(device)
        out = model(x)     
           
        # Metrics -> Maybe change to metric.update(), sin hacer precision = ...
        yhat = torch.sigmoid(out.detach())
        precision_metric.update(yhat, y)
        recall_metric.update(yhat, y)
        accuracy_metric.update(yhat, y)
        f1_metric.update(yhat, y)
    
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    accuracy = accuracy_metric.compute()
    f1 = f1_metric.compute()

    logger.info("VAL Metrics of Pytorch Model")
    print(f'SMOKE -> Precision: {precision[0]:.4f} - Recall: {recall[0]:.4f} - Accuracy: {accuracy[0]:.4f} - F1: {f1[0]:.4f}')
    logger.info(f'SMOKE -> Precision: {precision[0]:.4f} - Recall: {recall[0]:.4f} - Accuracy: {accuracy[0]:.4f} - F1: {f1[0]:.4f}')
    print(f'FIRE -> Precision: {precision[1]:.4f} - Recall: {recall[1]:.4f} - Accuracy: {accuracy[1]:.4f} - F1: {f1[1]:.4f}')
    logger.info(f'FIRE -> Precision: {precision[1]:.4f} - Recall: {recall[1]:.4f} - Accuracy: {accuracy[1]:.4f} - F1: {f1[1]:.4f}')
    
    precision_metric.reset()
    recall_metric.reset()
    accuracy_metric.reset()
    f1_metric.reset()
    
    return ({
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1': f1
    })

# %% [markdown]
# ## Evaluate Model

# %%
eval_metrics = eval_fn(
    val_loader, 
    model, 
    DEVICE)
# Out:
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 67/67 [00:03<00:00, 19.85it/s]
# SMOKE -> Precision: 0.9455 - Recall: 0.9413 - Accuracy: 0.9457 - F1: 0.9434
# FIRE -> Precision: 0.9594 - Recall: 0.9360 - Accuracy: 0.9732 - F1: 0.9476

# %% [markdown]
# # ONNX

# %% [markdown]
# ## Export

# %%
torch_input = torch.rand(1, 3, IMG_H, IMG_W)
model.to('cpu')
onnx_program = torch.onnx.dynamo_export(model, torch_input)
# Out:
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/onnx/_internal/exporter.py:136: UserWarning: torch.onnx.dynamo_export only implements opset version 18 for now. If you need to use a different opset version, please register them with register_custom_op.
#   warnings.warn(
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/onnx/_internal/fx/passes/readability.py:53: UserWarning: Attempted to insert a get_attr Node with no underlying reference in the owning GraphModule! Call GraphModule.add_submodule to add the necessary submodule, GraphModule.add_parameter to add the necessary Parameter, or nn.Module.register_buffer to add the necessary buffer
#   new_node = self.module.graph.get_attr(normalized_name)
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_0_1_running_mean target base_model/0/1/running_mean base_model/0/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_0_1_running_var target base_model/0/1/running_var base_model/0/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch1_1_running_mean target base_model/2/0/branch1/1/running_mean base_model/2/0/branch1/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch1_1_running_var target base_model/2/0/branch1/1/running_var base_model/2/0/branch1/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch1_3_running_mean target base_model/2/0/branch1/3/running_mean base_model/2/0/branch1/3/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch1_3_running_var target base_model/2/0/branch1/3/running_var base_model/2/0/branch1/3/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_1_running_mean target base_model/2/0/branch2/1/running_mean base_model/2/0/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_1_running_var target base_model/2/0/branch2/1/running_var base_model/2/0/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_4_running_mean target base_model/2/0/branch2/4/running_mean base_model/2/0/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_4_running_var target base_model/2/0/branch2/4/running_var base_model/2/0/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_6_running_mean target base_model/2/0/branch2/6/running_mean base_model/2/0/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_0_branch2_6_running_var target base_model/2/0/branch2/6/running_var base_model/2/0/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_1_running_mean target base_model/2/1/branch2/1/running_mean base_model/2/1/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_1_running_var target base_model/2/1/branch2/1/running_var base_model/2/1/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_4_running_mean target base_model/2/1/branch2/4/running_mean base_model/2/1/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_4_running_var target base_model/2/1/branch2/4/running_var base_model/2/1/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_6_running_mean target base_model/2/1/branch2/6/running_mean base_model/2/1/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_1_branch2_6_running_var target base_model/2/1/branch2/6/running_var base_model/2/1/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_1_running_mean target base_model/2/2/branch2/1/running_mean base_model/2/2/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_1_running_var target base_model/2/2/branch2/1/running_var base_model/2/2/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_4_running_mean target base_model/2/2/branch2/4/running_mean base_model/2/2/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_4_running_var target base_model/2/2/branch2/4/running_var base_model/2/2/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_6_running_mean target base_model/2/2/branch2/6/running_mean base_model/2/2/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_2_branch2_6_running_var target base_model/2/2/branch2/6/running_var base_model/2/2/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_1_running_mean target base_model/2/3/branch2/1/running_mean base_model/2/3/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_1_running_var target base_model/2/3/branch2/1/running_var base_model/2/3/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_4_running_mean target base_model/2/3/branch2/4/running_mean base_model/2/3/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_4_running_var target base_model/2/3/branch2/4/running_var base_model/2/3/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_6_running_mean target base_model/2/3/branch2/6/running_mean base_model/2/3/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_2_3_branch2_6_running_var target base_model/2/3/branch2/6/running_var base_model/2/3/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch1_1_running_mean target base_model/3/0/branch1/1/running_mean base_model/3/0/branch1/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch1_1_running_var target base_model/3/0/branch1/1/running_var base_model/3/0/branch1/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch1_3_running_mean target base_model/3/0/branch1/3/running_mean base_model/3/0/branch1/3/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch1_3_running_var target base_model/3/0/branch1/3/running_var base_model/3/0/branch1/3/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_1_running_mean target base_model/3/0/branch2/1/running_mean base_model/3/0/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_1_running_var target base_model/3/0/branch2/1/running_var base_model/3/0/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_4_running_mean target base_model/3/0/branch2/4/running_mean base_model/3/0/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_4_running_var target base_model/3/0/branch2/4/running_var base_model/3/0/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_6_running_mean target base_model/3/0/branch2/6/running_mean base_model/3/0/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_0_branch2_6_running_var target base_model/3/0/branch2/6/running_var base_model/3/0/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_1_running_mean target base_model/3/1/branch2/1/running_mean base_model/3/1/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_1_running_var target base_model/3/1/branch2/1/running_var base_model/3/1/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_4_running_mean target base_model/3/1/branch2/4/running_mean base_model/3/1/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_4_running_var target base_model/3/1/branch2/4/running_var base_model/3/1/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_6_running_mean target base_model/3/1/branch2/6/running_mean base_model/3/1/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_1_branch2_6_running_var target base_model/3/1/branch2/6/running_var base_model/3/1/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_1_running_mean target base_model/3/2/branch2/1/running_mean base_model/3/2/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_1_running_var target base_model/3/2/branch2/1/running_var base_model/3/2/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_4_running_mean target base_model/3/2/branch2/4/running_mean base_model/3/2/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_4_running_var target base_model/3/2/branch2/4/running_var base_model/3/2/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_6_running_mean target base_model/3/2/branch2/6/running_mean base_model/3/2/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_2_branch2_6_running_var target base_model/3/2/branch2/6/running_var base_model/3/2/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_1_running_mean target base_model/3/3/branch2/1/running_mean base_model/3/3/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_1_running_var target base_model/3/3/branch2/1/running_var base_model/3/3/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_4_running_mean target base_model/3/3/branch2/4/running_mean base_model/3/3/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_4_running_var target base_model/3/3/branch2/4/running_var base_model/3/3/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_6_running_mean target base_model/3/3/branch2/6/running_mean base_model/3/3/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_3_branch2_6_running_var target base_model/3/3/branch2/6/running_var base_model/3/3/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_1_running_mean target base_model/3/4/branch2/1/running_mean base_model/3/4/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_1_running_var target base_model/3/4/branch2/1/running_var base_model/3/4/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_4_running_mean target base_model/3/4/branch2/4/running_mean base_model/3/4/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_4_running_var target base_model/3/4/branch2/4/running_var base_model/3/4/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_6_running_mean target base_model/3/4/branch2/6/running_mean base_model/3/4/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_4_branch2_6_running_var target base_model/3/4/branch2/6/running_var base_model/3/4/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_1_running_mean target base_model/3/5/branch2/1/running_mean base_model/3/5/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_1_running_var target base_model/3/5/branch2/1/running_var base_model/3/5/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_4_running_mean target base_model/3/5/branch2/4/running_mean base_model/3/5/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_4_running_var target base_model/3/5/branch2/4/running_var base_model/3/5/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_6_running_mean target base_model/3/5/branch2/6/running_mean base_model/3/5/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_5_branch2_6_running_var target base_model/3/5/branch2/6/running_var base_model/3/5/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_1_running_mean target base_model/3/6/branch2/1/running_mean base_model/3/6/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_1_running_var target base_model/3/6/branch2/1/running_var base_model/3/6/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_4_running_mean target base_model/3/6/branch2/4/running_mean base_model/3/6/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_4_running_var target base_model/3/6/branch2/4/running_var base_model/3/6/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_6_running_mean target base_model/3/6/branch2/6/running_mean base_model/3/6/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_6_branch2_6_running_var target base_model/3/6/branch2/6/running_var base_model/3/6/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_1_running_mean target base_model/3/7/branch2/1/running_mean base_model/3/7/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_1_running_var target base_model/3/7/branch2/1/running_var base_model/3/7/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_4_running_mean target base_model/3/7/branch2/4/running_mean base_model/3/7/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_4_running_var target base_model/3/7/branch2/4/running_var base_model/3/7/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_6_running_mean target base_model/3/7/branch2/6/running_mean base_model/3/7/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_3_7_branch2_6_running_var target base_model/3/7/branch2/6/running_var base_model/3/7/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch1_1_running_mean target base_model/4/0/branch1/1/running_mean base_model/4/0/branch1/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch1_1_running_var target base_model/4/0/branch1/1/running_var base_model/4/0/branch1/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch1_3_running_mean target base_model/4/0/branch1/3/running_mean base_model/4/0/branch1/3/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch1_3_running_var target base_model/4/0/branch1/3/running_var base_model/4/0/branch1/3/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_1_running_mean target base_model/4/0/branch2/1/running_mean base_model/4/0/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_1_running_var target base_model/4/0/branch2/1/running_var base_model/4/0/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_4_running_mean target base_model/4/0/branch2/4/running_mean base_model/4/0/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_4_running_var target base_model/4/0/branch2/4/running_var base_model/4/0/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_6_running_mean target base_model/4/0/branch2/6/running_mean base_model/4/0/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_0_branch2_6_running_var target base_model/4/0/branch2/6/running_var base_model/4/0/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_1_running_mean target base_model/4/1/branch2/1/running_mean base_model/4/1/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_1_running_var target base_model/4/1/branch2/1/running_var base_model/4/1/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_4_running_mean target base_model/4/1/branch2/4/running_mean base_model/4/1/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_4_running_var target base_model/4/1/branch2/4/running_var base_model/4/1/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_6_running_mean target base_model/4/1/branch2/6/running_mean base_model/4/1/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_1_branch2_6_running_var target base_model/4/1/branch2/6/running_var base_model/4/1/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_1_running_mean target base_model/4/2/branch2/1/running_mean base_model/4/2/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_1_running_var target base_model/4/2/branch2/1/running_var base_model/4/2/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_4_running_mean target base_model/4/2/branch2/4/running_mean base_model/4/2/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_4_running_var target base_model/4/2/branch2/4/running_var base_model/4/2/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_6_running_mean target base_model/4/2/branch2/6/running_mean base_model/4/2/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_2_branch2_6_running_var target base_model/4/2/branch2/6/running_var base_model/4/2/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_1_running_mean target base_model/4/3/branch2/1/running_mean base_model/4/3/branch2/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_1_running_var target base_model/4/3/branch2/1/running_var base_model/4/3/branch2/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_4_running_mean target base_model/4/3/branch2/4/running_mean base_model/4/3/branch2/4/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_4_running_var target base_model/4/3/branch2/4/running_var base_model/4/3/branch2/4/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_6_running_mean target base_model/4/3/branch2/6/running_mean base_model/4/3/branch2/6/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_4_3_branch2_6_running_var target base_model/4/3/branch2/6/running_var base_model/4/3/branch2/6/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_5_1_running_mean target base_model/5/1/running_mean base_model/5/1/running_mean of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '
# /opt/conda/envs/pytorch_23/lib/python3.10/site-packages/torch/fx/graph.py:1460: UserWarning: Node base_model_5_1_running_var target base_model/5/1/running_var base_model/5/1/running_var of  does not reference an nn.Module, nn.Parameter, or buffer, which is what 'get_attr' Nodes typically target
#   warnings.warn(f'Node {node} target {node.target} {atom} of {seen_qualname} does '

# %% [markdown]
# ## Save, Load & Check

# %%
onnx_program.save("shufflenet_classifier.onnx")

# %%
classifier = onnx.load('shufflenet_classifier.onnx')
onnx.checker.check_model(classifier)

# %% [markdown]
# ## Metrics to CPU for ONNX evaluation

# %%
precision_metric = torchmetrics.classification.MultilabelPrecision(num_labels = N_CLASSES, 
                                                                   threshold = 0.5, 
                                                                   average = None).to('cpu')
recall_metric = torchmetrics.classification.MultilabelRecall(num_labels = N_CLASSES, 
                                                             threshold = 0.5, 
                                                             average = None).to('cpu')
accuracy_metric = torchmetrics.classification.MultilabelAccuracy(num_labels = N_CLASSES, 
                                                                 threshold = 0.5, 
                                                                 average = None).to('cpu')
f1_metric = torchmetrics.classification.MultilabelF1Score(num_labels = N_CLASSES, 
                                                          threshold = 0.5, 
                                                          average = None).to('cpu')

f1_metric_mean = torchmetrics.classification.MultilabelF1Score(num_labels = N_CLASSES, 
                                                               threshold = 0.5, 
                                                               average = 'macro').to('cpu')

# %% [markdown]
# ## Eval Function

# %%
def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# %%
def eval_classifier_onnx(loader, model_name):

    ort_session = onnxruntime.InferenceSession(model_name, providers=["CPUExecutionProvider"])

    precision_metric.reset()
    recall_metric.reset()
    accuracy_metric.reset()
    f1_metric.reset()
    f1_metric_mean.reset()
    
    loop = tqdm(loader, desc='Validating', leave=True)

    for batch_idx, (img, label) in enumerate(loop):

        for idx in range(BATCH_SIZE):
            
            ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(img[idx].unsqueeze(dim=0))}
            yhat = ort_session.run(None, ort_inputs)
            yhat = np.array(yhat)
            #yhat = torch.tensor(yhat).squeeze(dim=0)
            yhat = torch.sigmoid(torch.tensor(yhat).squeeze(dim=0))
            target = label[idx].unsqueeze(dim=0)

            precision_metric.update(yhat, target)
            recall_metric.update(yhat, target)
            accuracy_metric.update(yhat, target)
            f1_metric.update(yhat, target)
            f1_metric_mean.update(yhat, target)
    
    precision = precision_metric.compute()
    recall = recall_metric.compute()
    accuracy = accuracy_metric.compute()
    f1 = f1_metric.compute()
    f1_mean = f1_metric_mean.compute()

    precision_metric.reset()
    recall_metric.reset()
    accuracy_metric.reset()
    f1_metric.reset()
    f1_metric_mean.reset()

    print(f'SMOKE -> Precision: {precision[0]:.4f} - Recall: {recall[0]:.4f} - Accuracy: {accuracy[0]:.4f} - F1: {f1[0]:.4f}')
    print(f'FIRE -> Precision: {precision[1]:.4f} - Recall: {recall[1]:.4f} - Accuracy: {accuracy[1]:.4f} - F1: {f1[1]:.4f}')
    print(f'Mean F1 Score: {f1_mean.item():.4f}')

    logger.info(f'SMOKE -> Precision: {precision[0]:.4f} - Recall: {recall[0]:.4f} - Accuracy: {accuracy[0]:.4f} - F1: {f1[0]:.4f}')
    logger.info(f'FIRE -> Precision: {precision[1]:.4f} - Recall: {recall[1]:.4f} - Accuracy: {accuracy[1]:.4f} - F1: {f1[1]:.4f}')
    logger.info(f'Mean F1 Score: {f1_mean.item():.4f}')
    
    return (
        {
        'Accuracy': [accuracy[0].item(), accuracy[1].item()],
        'Precision': [precision[0].item(), precision[1].item()],
        'Recall': [recall[0].item(), recall[1].item()],
        'F1': [f1[0].item(), f1[1].item()],
        'F1 mean': f1_mean.item(),
        }
    )

# %%
logger.info("\nONNX Metrics")
onnx_metrics = eval_classifier_onnx(val_loader, 'shufflenet_classifier.onnx')
# Out:
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 67/67 [00:13<00:00,  4.93it/s]
# SMOKE -> Precision: 0.9450 - Recall: 0.9418 - Accuracy: 0.9457 - F1: 0.9434
# FIRE -> Precision: 0.9585 - Recall: 0.9360 - Accuracy: 0.9729 - F1: 0.9471
# Mean F1 Score: 0.9453

# %%
print('Pytorch Model metrics to compare')
for k in eval_metrics.keys():
    print(f'{k}\n  Smoke: {eval_metrics[k][0]:.4f}\n  Fire: {eval_metrics[k][1]:.4f}')
# Out:
# Pytorch Model metrics to compare
# Accuracy
#   Smoke: 0.9457
#   Fire: 0.9732
# Precision
#   Smoke: 0.9455
#   Fire: 0.9594
# Recall
#   Smoke: 0.9413
#   Fire: 0.9360
# F1
#   Smoke: 0.9434
#   Fire: 0.9476
