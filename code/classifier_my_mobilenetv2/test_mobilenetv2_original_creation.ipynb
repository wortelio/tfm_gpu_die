# %%
import modules.models.model_mobilenetv2_original as mbnetv2
import modules.models.model_mobilenetv2_v3_last_stage_original as mbnetv2_v3


import numpy as np
import torch
from torchinfo import summary

import matplotlib.pyplot as plt

# %% [markdown]
# # Profiler: torchprofile

# %%
from torchprofile import profile_macs

# %% [markdown]
# # Profiler: torchlop

# %%
from torchlop import profile

# %%
def get_macs_and_params_per_layer(model):

    dummy_inp = torch.randn(1, 3, 224, 224)
    macs, params, layer_infos = profile(model, inputs=(dummy_inp, ))

    print('Total MACs of {}: {:.4g} M'.format(model.__class__.__name__, macs / 1e6))
    print('Total params of {}: {}'.format(model.__class__.__name__, params))

    macs_layer = {}
    params_layer = {}

    conv_idx = 0
    linear_idx = 0
    
    for i, k in enumerate(layer_infos.keys()):
        layer_type = layer_infos[k]["type"]
        layer_ops = layer_infos[k]["ops"]
        layer_params = layer_infos[k]["params"]
        if layer_ops != 0 and layer_type != "BatchNorm2d":
            if layer_type == "Conv2d": 
                macs_layer.update({layer_type + '_' + str(conv_idx): layer_ops})   
                params_layer.update({layer_type + '_' + str(conv_idx): layer_params}) 
                conv_idx += 1
            elif layer_type == "Linear":
                macs_layer.update({layer_type + '_' + str(linear_idx): layer_ops}) 
                params_layer.update({layer_type + '_' + str(linear_idx): layer_params})  
                linear_idx += 1 
            else:
                macs_layer.update({layer_type: layer_ops})
                params_layer.update({layer_type: layer_params})

    return macs_layer, params_layer

# %% [markdown]
# ## Plot results

# %%
def plot_results(res_layer, res_type: str):
    fig, ax = plt.subplots(figsize=(10,3))

    layers_name = list(res_layer.keys())
    layer_res = list(res_layer.values())
    
    rects = ax.bar(layers_name, layer_res)
    ax.bar_label(rects, padding=3, fontsize=7)
    if res_type == "macs":
        ylabel = "MACs (M)"
        title = "MACs per layer (M)"
    elif res_type == "params":
        ylabel = "#Params"  
        title = "#Params per layer"
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.set_xticks(np.arange(len(layers_name)), layers_name, rotation=90, fontsize=8)
    
    plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# ### Original

# %%
model = mbnetv2.MobileNetV2().to('cpu')

# %%
model_01 = mbnetv2.MobileNetV2(width_mult=0.1).to('cpu')

# %%
model.eval();
model_01.eval();

# %% [markdown]
# ### Last Stage Modified

# %%
modelv2_v3 = mbnetv2_v3.MobileNetV2_V3().to('cpu')
modelv2_v3.eval();

# %% [markdown]
# # MobileNetV2

# %% [markdown]
# ### Profile

# %%
inputs = torch.randn(1, 3, 224, 224)

macs = profile_macs(model, inputs)
print('{}: {:.4g} M'.format(model.__class__.__name__, macs / 1e6))
# Out:
# MobileNetV2: 306.2 M

# %%
macs_mbnet, params_mbnet = get_macs_and_params_per_layer(model)
# Out:
# Total MACs of MobileNetV2: 312.9 M
# Total params of MobileNetV2: 2226434.0

# %%
plot_results(macs_mbnet, res_type="macs")

# %%
plot_results(params_mbnet, res_type="params")

# %% [markdown]
# ### Summary

# %%
print(summary(model, input_size=(1, 3, 224, 224)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MobileNetV2                              [1, 2]                    --
# ├─Sequential: 1-1                        [1, 320, 7, 7]            --
# │    └─Sequential: 2-1                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         864
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─ReLU6: 3-3                   [1, 32, 112, 112]         --
# │    └─InvertedResidual: 2-2             [1, 16, 112, 112]         --
# │    │    └─Sequential: 3-4              [1, 16, 112, 112]         896
# │    └─InvertedResidual: 2-3             [1, 24, 56, 56]           --
# │    │    └─Sequential: 3-5              [1, 24, 56, 56]           5,136
# │    └─InvertedResidual: 2-4             [1, 24, 56, 56]           --
# │    │    └─Sequential: 3-6              [1, 24, 56, 56]           8,832
# │    └─InvertedResidual: 2-5             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-7              [1, 32, 28, 28]           10,000
# │    └─InvertedResidual: 2-6             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-8              [1, 32, 28, 28]           14,848
# │    └─InvertedResidual: 2-7             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-9              [1, 32, 28, 28]           14,848
# │    └─InvertedResidual: 2-8             [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-10             [1, 64, 14, 14]           21,056
# │    └─InvertedResidual: 2-9             [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-11             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-10            [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-12             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-11            [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-13             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-12            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-14             [1, 96, 14, 14]           66,624
# │    └─InvertedResidual: 2-13            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-15             [1, 96, 14, 14]           118,272
# │    └─InvertedResidual: 2-14            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-16             [1, 96, 14, 14]           118,272
# │    └─InvertedResidual: 2-15            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-17             [1, 160, 7, 7]            155,264
# │    └─InvertedResidual: 2-16            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-18             [1, 160, 7, 7]            320,000
# │    └─InvertedResidual: 2-17            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-19             [1, 160, 7, 7]            320,000
# │    └─InvertedResidual: 2-18            [1, 320, 7, 7]            --
# │    │    └─Sequential: 3-20             [1, 320, 7, 7]            473,920
# ├─Sequential: 1-2                        [1, 1280, 7, 7]           --
# │    └─Conv2d: 2-19                      [1, 1280, 7, 7]           409,600
# │    └─BatchNorm2d: 2-20                 [1, 1280, 7, 7]           2,560
# │    └─ReLU6: 2-21                       [1, 1280, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-3                 [1, 1280, 1, 1]           --
# ├─Linear: 1-4                            [1, 2]                    2,562
# ==========================================================================================
# Total params: 2,226,434
# Trainable params: 2,226,434
# Non-trainable params: 0
# Total mult-adds (M): 299.53
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 106.85
# Params size (MB): 8.91
# Estimated Total Size (MB): 116.36
# ==========================================================================================

# %%
# model

# %% [markdown]
# # Width Mult = 0.1

# %%
inputs = torch.randn(1, 3, 224, 224)

macs = profile_macs(model_01, inputs)
print('{}: {:.4g} M'.format(model_01.__class__.__name__, macs / 1e6))
# Out:
# MobileNetV2: 12.8 M

# %%
macs_mbnet, params_mbnet = get_macs_and_params_per_layer(model_01)
# Out:
# Total MACs of MobileNetV2: 14.03 M
# Total params of MobileNetV2: 78258.0

# %%
plot_results(macs_mbnet, res_type="macs")

# %%
plot_results(params_mbnet, res_type="params")

# %% [markdown]
# ### Summary

# %%
print(summary(model_01, input_size=(1, 3, 224, 224)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MobileNetV2                              [1, 2]                    --
# ├─Sequential: 1-1                        [1, 32, 7, 7]             --
# │    └─Sequential: 2-1                   [1, 4, 112, 112]          --
# │    │    └─Conv2d: 3-1                  [1, 4, 112, 112]          108
# │    │    └─BatchNorm2d: 3-2             [1, 4, 112, 112]          8
# │    │    └─ReLU6: 3-3                   [1, 4, 112, 112]          --
# │    └─InvertedResidual: 2-2             [1, 4, 112, 112]          --
# │    │    └─Sequential: 3-4              [1, 4, 112, 112]          68
# │    └─InvertedResidual: 2-3             [1, 4, 56, 56]            --
# │    │    └─Sequential: 3-5              [1, 4, 56, 56]            512
# │    └─InvertedResidual: 2-4             [1, 4, 56, 56]            --
# │    │    └─Sequential: 3-6              [1, 4, 56, 56]            512
# │    └─InvertedResidual: 2-5             [1, 4, 28, 28]            --
# │    │    └─Sequential: 3-7              [1, 4, 28, 28]            512
# │    └─InvertedResidual: 2-6             [1, 4, 28, 28]            --
# │    │    └─Sequential: 3-8              [1, 4, 28, 28]            512
# │    └─InvertedResidual: 2-7             [1, 4, 28, 28]            --
# │    │    └─Sequential: 3-9              [1, 4, 28, 28]            512
# │    └─InvertedResidual: 2-8             [1, 8, 14, 14]            --
# │    │    └─Sequential: 3-10             [1, 8, 14, 14]            616
# │    └─InvertedResidual: 2-9             [1, 8, 14, 14]            --
# │    │    └─Sequential: 3-11             [1, 8, 14, 14]            1,408
# │    └─InvertedResidual: 2-10            [1, 8, 14, 14]            --
# │    │    └─Sequential: 3-12             [1, 8, 14, 14]            1,408
# │    └─InvertedResidual: 2-11            [1, 8, 14, 14]            --
# │    │    └─Sequential: 3-13             [1, 8, 14, 14]            1,408
# │    └─InvertedResidual: 2-12            [1, 12, 14, 14]           --
# │    │    └─Sequential: 3-14             [1, 12, 14, 14]           1,608
# │    └─InvertedResidual: 2-13            [1, 12, 14, 14]           --
# │    │    └─Sequential: 3-15             [1, 12, 14, 14]           2,688
# │    └─InvertedResidual: 2-14            [1, 12, 14, 14]           --
# │    │    └─Sequential: 3-16             [1, 12, 14, 14]           2,688
# │    └─InvertedResidual: 2-15            [1, 16, 7, 7]             --
# │    │    └─Sequential: 3-17             [1, 16, 7, 7]             2,984
# │    └─InvertedResidual: 2-16            [1, 16, 7, 7]             --
# │    │    └─Sequential: 3-18             [1, 16, 7, 7]             4,352
# │    └─InvertedResidual: 2-17            [1, 16, 7, 7]             --
# │    │    └─Sequential: 3-19             [1, 16, 7, 7]             4,352
# │    └─InvertedResidual: 2-18            [1, 32, 7, 7]             --
# │    │    └─Sequential: 3-20             [1, 32, 7, 7]             5,920
# ├─Sequential: 1-2                        [1, 1280, 7, 7]           --
# │    └─Conv2d: 2-19                      [1, 1280, 7, 7]           40,960
# │    └─BatchNorm2d: 2-20                 [1, 1280, 7, 7]           2,560
# │    └─ReLU6: 2-21                       [1, 1280, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-3                 [1, 1280, 1, 1]           --
# ├─Linear: 1-4                            [1, 2]                    2,562
# ==========================================================================================
# Total params: 78,258
# Trainable params: 78,258
# Non-trainable params: 0
# Total mult-adds (M): 11.65
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 18.60
# Params size (MB): 0.31
# Estimated Total Size (MB): 19.51
# ==========================================================================================

# %% [markdown]
# # MobileNetV2 Final Stage V3

# %% [markdown]
# ### Profile

# %%
inputs = torch.randn(1, 3, 224, 224)

macs = profile_macs(modelv2_v3, inputs)
print('{}: {:.4g} M'.format(modelv2_v3.__class__.__name__, macs / 1e6))
# Out:
# MobileNetV2_V3: 271.7 M

# %%
macs_mbnet, params_mbnet = get_macs_and_params_per_layer(modelv2_v3)
# Out:
# Total MACs of MobileNetV2_V3: 278.3 M
# Total params of MobileNetV2_V3: 2727234.0

# %%
plot_results(macs_mbnet, res_type="macs")

# %%
plot_results(params_mbnet, res_type="params")

# %% [markdown]
# ### Summary

# %%
print(summary(modelv2_v3, input_size=(1, 3, 224, 224)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MobileNetV2_V3                           [1, 2]                    --
# ├─Sequential: 1-1                        [1, 160, 7, 7]            --
# │    └─Sequential: 2-1                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         864
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─ReLU6: 3-3                   [1, 32, 112, 112]         --
# │    └─InvertedResidual: 2-2             [1, 16, 112, 112]         --
# │    │    └─Sequential: 3-4              [1, 16, 112, 112]         896
# │    └─InvertedResidual: 2-3             [1, 24, 56, 56]           --
# │    │    └─Sequential: 3-5              [1, 24, 56, 56]           5,136
# │    └─InvertedResidual: 2-4             [1, 24, 56, 56]           --
# │    │    └─Sequential: 3-6              [1, 24, 56, 56]           8,832
# │    └─InvertedResidual: 2-5             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-7              [1, 32, 28, 28]           10,000
# │    └─InvertedResidual: 2-6             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-8              [1, 32, 28, 28]           14,848
# │    └─InvertedResidual: 2-7             [1, 32, 28, 28]           --
# │    │    └─Sequential: 3-9              [1, 32, 28, 28]           14,848
# │    └─InvertedResidual: 2-8             [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-10             [1, 64, 14, 14]           21,056
# │    └─InvertedResidual: 2-9             [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-11             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-10            [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-12             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-11            [1, 64, 14, 14]           --
# │    │    └─Sequential: 3-13             [1, 64, 14, 14]           54,272
# │    └─InvertedResidual: 2-12            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-14             [1, 96, 14, 14]           66,624
# │    └─InvertedResidual: 2-13            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-15             [1, 96, 14, 14]           118,272
# │    └─InvertedResidual: 2-14            [1, 96, 14, 14]           --
# │    │    └─Sequential: 3-16             [1, 96, 14, 14]           118,272
# │    └─InvertedResidual: 2-15            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-17             [1, 160, 7, 7]            155,264
# │    └─InvertedResidual: 2-16            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-18             [1, 160, 7, 7]            320,000
# │    └─InvertedResidual: 2-17            [1, 160, 7, 7]            --
# │    │    └─Sequential: 3-19             [1, 160, 7, 7]            320,000
# ├─Sequential: 1-2                        [1, 960, 7, 7]            --
# │    └─Conv2d: 2-18                      [1, 960, 7, 7]            153,600
# │    └─BatchNorm2d: 2-19                 [1, 960, 7, 7]            1,920
# │    └─ReLU6: 2-20                       [1, 960, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-3                 [1, 960, 1, 1]            --
# ├─Sequential: 1-4                        [1, 1280, 1, 1]           --
# │    └─Conv2d: 2-21                      [1, 1280, 1, 1]           1,228,800
# │    └─BatchNorm2d: 2-22                 [1, 1280, 1, 1]           2,560
# │    └─ReLU6: 2-23                       [1, 1280, 1, 1]           --
# ├─Linear: 1-5                            [1, 2]                    2,562
# ==========================================================================================
# Total params: 2,727,234
# Trainable params: 2,727,234
# Non-trainable params: 0
# Total mult-adds (M): 265.21
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.86
# Params size (MB): 10.91
# Estimated Total Size (MB): 116.37
# ==========================================================================================

# %% [markdown]
# # Export to ONNX

# %%
# model.cpu();

# %%
# torch_input = torch.randn(1, 3, 224, 224)
# torch.onnx.export(model, torch_input, "mbnet_original.onnx")
