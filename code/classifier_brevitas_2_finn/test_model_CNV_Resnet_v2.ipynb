# %%
import modules.models.model_torch_CNV_w1a1_DEEP_Resnet_V2 as torch_cnv_deep_resnet
import modules.models.model_CNV_w1a1_DEEP_Resnet_V2 as cnv_deep_resnet

import numpy as np
import torch
from torchinfo import summary

# %% [markdown]
# # Model

# %%
torch_model = torch_cnv_deep_resnet.Torch_CNV_w1a1_DEEP_Resnet().to('cpu')
brevitas_model = cnv_deep_resnet.CNV_w1a1_DEEP_Resnet().to('cpu')

# %%
torch_model.eval();
brevitas_model.eval();

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Torch

# %%
print(summary(torch_model, input_size=(1, 3, 224, 224)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Torch_CNV_w1a1_DEEP_Resnet               [1, 2]                    --
# ├─ModuleList: 1-1                        --                        --
# │    └─Conv2d: 2-1                       [1, 64, 224, 224]         1,728
# │    └─BatchNorm2d: 2-2                  [1, 64, 224, 224]         128
# │    └─ReLU: 2-3                         [1, 64, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 64, 112, 112]         --
# │    └─Conv2d: 2-5                       [1, 32, 112, 112]         18,432
# │    └─BatchNorm2d: 2-6                  [1, 32, 112, 112]         64
# │    └─ReLU: 2-7                         [1, 32, 112, 112]         --
# │    └─MaxPool2d: 2-8                    [1, 32, 56, 56]           --
# ├─ModuleList: 1-2                        --                        --
# │    └─Conv2d: 2-9                       [1, 16, 56, 56]           512
# │    └─BatchNorm2d: 2-10                 [1, 16, 56, 56]           32
# │    └─ReLU: 2-11                        [1, 16, 56, 56]           --
# │    └─Conv2d: 2-12                      [1, 32, 56, 56]           4,608
# │    └─BatchNorm2d: 2-13                 [1, 32, 56, 56]           64
# │    └─ReLU: 2-14                        [1, 32, 56, 56]           --
# │    └─Conv2d: 2-15                      [1, 32, 56, 56]           1,024
# │    └─BatchNorm2d: 2-16                 [1, 32, 56, 56]           64
# │    └─ReLU: 2-17                        [1, 32, 56, 56]           --
# ├─ReLU: 1-3                              [1, 32, 56, 56]           --
# ├─ModuleList: 1-4                        --                        --
# │    └─Conv2d: 2-18                      [1, 64, 56, 56]           18,432
# │    └─BatchNorm2d: 2-19                 [1, 64, 56, 56]           128
# │    └─ReLU: 2-20                        [1, 64, 56, 56]           --
# │    └─MaxPool2d: 2-21                   [1, 64, 28, 28]           --
# ├─ModuleList: 1-5                        --                        --
# │    └─Conv2d: 2-22                      [1, 32, 28, 28]           2,048
# │    └─BatchNorm2d: 2-23                 [1, 32, 28, 28]           64
# │    └─ReLU: 2-24                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-25                      [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-26                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-27                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-28                      [1, 32, 28, 28]           2,048
# │    └─BatchNorm2d: 2-29                 [1, 32, 28, 28]           64
# │    └─ReLU: 2-30                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-31                      [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-32                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-33                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-34                      [1, 64, 28, 28]           4,096
# │    └─BatchNorm2d: 2-35                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-36                        [1, 64, 28, 28]           --
# ├─ReLU: 1-6                              [1, 64, 28, 28]           --
# ├─ModuleList: 1-7                        --                        --
# │    └─Conv2d: 2-37                      [1, 96, 28, 28]           55,296
# │    └─BatchNorm2d: 2-38                 [1, 96, 28, 28]           192
# │    └─ReLU: 2-39                        [1, 96, 28, 28]           --
# │    └─MaxPool2d: 2-40                   [1, 96, 14, 14]           --
# ├─ModuleList: 1-8                        --                        --
# │    └─Conv2d: 2-41                      [1, 48, 14, 14]           4,608
# │    └─BatchNorm2d: 2-42                 [1, 48, 14, 14]           96
# │    └─ReLU: 2-43                        [1, 48, 14, 14]           --
# │    └─Conv2d: 2-44                      [1, 96, 14, 14]           41,472
# │    └─BatchNorm2d: 2-45                 [1, 96, 14, 14]           192
# │    └─ReLU: 2-46                        [1, 96, 14, 14]           --
# │    └─Conv2d: 2-47                      [1, 48, 14, 14]           4,608
# │    └─BatchNorm2d: 2-48                 [1, 48, 14, 14]           96
# │    └─ReLU: 2-49                        [1, 48, 14, 14]           --
# │    └─Conv2d: 2-50                      [1, 96, 14, 14]           41,472
# │    └─BatchNorm2d: 2-51                 [1, 96, 14, 14]           192
# │    └─ReLU: 2-52                        [1, 96, 14, 14]           --
# │    └─Conv2d: 2-53                      [1, 96, 14, 14]           9,216
# │    └─BatchNorm2d: 2-54                 [1, 96, 14, 14]           192
# │    └─ReLU: 2-55                        [1, 96, 14, 14]           --
# ├─ReLU: 1-9                              [1, 96, 14, 14]           --
# ├─ModuleList: 1-10                       --                        --
# │    └─Conv2d: 2-56                      [1, 128, 14, 14]          110,592
# │    └─BatchNorm2d: 2-57                 [1, 128, 14, 14]          256
# │    └─ReLU: 2-58                        [1, 128, 14, 14]          --
# │    └─MaxPool2d: 2-59                   [1, 128, 7, 7]            --
# ├─ModuleList: 1-11                       --                        --
# │    └─Conv2d: 2-60                      [1, 128, 7, 7]            147,456
# │    └─BatchNorm2d: 2-61                 [1, 128, 7, 7]            256
# │    └─ReLU: 2-62                        [1, 128, 7, 7]            --
# │    └─Conv2d: 2-63                      [1, 128, 7, 7]            147,456
# │    └─BatchNorm2d: 2-64                 [1, 128, 7, 7]            256
# │    └─ReLU: 2-65                        [1, 128, 7, 7]            --
# ├─ReLU: 1-12                             [1, 128, 7, 7]            --
# ├─AvgPool2d: 1-13                        [1, 128, 1, 1]            --
# ├─ModuleList: 1-14                       --                        --
# │    └─Linear: 2-66                      [1, 64]                   8,192
# │    └─BatchNorm1d: 2-67                 [1, 64]                   128
# │    └─ReLU: 2-68                        [1, 64]                   --
# │    └─Linear: 2-69                      [1, 32]                   2,048
# │    └─BatchNorm1d: 2-70                 [1, 32]                   64
# │    └─ReLU: 2-71                        [1, 32]                   --
# │    └─Linear: 2-72                      [1, 2]                    64
# ==========================================================================================
# Total params: 665,184
# Trainable params: 665,184
# Non-trainable params: 0
# Total mult-adds (M): 529.67
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 71.25
# Params size (MB): 2.66
# Estimated Total Size (MB): 74.51
# ==========================================================================================

# %% [markdown]
# ### Brevitas

# %%
print(summary(brevitas_model, input_size=(1, 3, 224, 224)))
# Out:
# ========================================================================================================================
# Layer (type:depth-idx)                                                 Output Shape              Param #
# ========================================================================================================================
# CNV_w1a1_DEEP_Resnet                                                   [1, 2]                    --
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantIdentity: 2-1                                              [1, 3, 224, 224]          --
# │    │    └─ActQuantProxyFromInjector: 3-1                             [1, 3, 224, 224]          --
# │    │    └─ActQuantProxyFromInjector: 3-2                             [1, 3, 224, 224]          --
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantIdentity: 2-5                                              --                        --
# │    │    └─ActQuantProxyFromInjector: 3-6                             --                        --
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantReLU: 2-147                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-183                           --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantIdentity: 2-5                                              --                        --
# │    │    └─ActQuantProxyFromInjector: 3-6                             --                        --
# │    └─QuantConv2d: 2-6                                                [1, 64, 224, 224]         --
# │    │    └─ActQuantProxyFromInjector: 3-7                             [1, 3, 224, 224]          --
# │    │    └─WeightQuantProxyFromInjector: 3-8                          [64, 3, 3, 3]             1,728
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantConv2d: 2-8                                                --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-10                         --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-11                            [1, 64, 224, 224]         --
# │    └─BatchNorm2d: 2-9                                                [1, 64, 224, 224]         128
# │    └─QuantReLU: 2-10                                                 [1, 64, 224, 224]         --
# │    │    └─ActQuantProxyFromInjector: 3-12                            [1, 64, 224, 224]         --
# │    │    └─ActQuantProxyFromInjector: 3-13                            [1, 64, 224, 224]         1
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantReLU: 2-14                                                 --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-17                            --                        (recursive)
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantReLU: 2-147                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-183                           --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantReLU: 2-14                                                 --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-17                            --                        (recursive)
# │    └─MaxPool2d: 2-15                                                 [1, 64, 112, 112]         --
# │    └─QuantConv2d: 2-16                                               [1, 32, 112, 112]         --
# │    │    └─ActQuantProxyFromInjector: 3-18                            [1, 64, 112, 112]         --
# │    │    └─WeightQuantProxyFromInjector: 3-19                         [32, 64, 3, 3]            18,432
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantConv2d: 2-18                                               --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-21                         --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-22                            [1, 32, 112, 112]         --
# │    └─BatchNorm2d: 2-19                                               [1, 32, 112, 112]         64
# │    └─QuantIdentity: 2-20                                             [1, 32, 112, 112]         --
# │    │    └─ActQuantProxyFromInjector: 3-23                            [1, 32, 112, 112]         --
# │    │    └─ActQuantProxyFromInjector: 3-24                            [1, 32, 112, 112]         --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-15                                                     --                        (recursive)
# │    └─QuantIdentity: 2-22                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-26                            --                        --
# │    └─MaxPool2d: 2-23                                                 [1, 32, 56, 56]           --
# ├─ModuleList: 1-22                                                     --                        (recursive)
# │    └─QuantConv2d: 2-24                                               [1, 16, 56, 56]           512
# │    │    └─ActQuantProxyFromInjector: 3-27                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-28                         [16, 32, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-29                            [1, 16, 56, 56]           --
# │    └─BatchNorm2d: 2-25                                               [1, 16, 56, 56]           32
# │    └─QuantIdentity: 2-26                                             [1, 16, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-30                            [1, 16, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-31                            [1, 16, 56, 56]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-22                                                     --                        (recursive)
# │    └─QuantIdentity: 2-28                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-33                            --                        --
# │    └─QuantConv2d: 2-29                                               [1, 32, 56, 56]           4,608
# │    │    └─ActQuantProxyFromInjector: 3-34                            [1, 16, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-35                         [32, 16, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-36                            [1, 32, 56, 56]           --
# │    └─BatchNorm2d: 2-30                                               [1, 32, 56, 56]           64
# │    └─QuantIdentity: 2-31                                             [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-37                            [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-38                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-22                                                     --                        (recursive)
# │    └─QuantIdentity: 2-33                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-40                            --                        --
# │    └─QuantConv2d: 2-34                                               [1, 32, 56, 56]           1,024
# │    │    └─ActQuantProxyFromInjector: 3-41                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-42                         [32, 32, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-43                            [1, 32, 56, 56]           --
# │    └─BatchNorm2d: 2-35                                               [1, 32, 56, 56]           64
# │    └─QuantIdentity: 2-36                                             [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-44                            [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-45                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-22                                                     --                        (recursive)
# │    └─QuantIdentity: 2-38                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-47                            --                        --
# ├─QuantIdentity: 1-23                                                  [1, 32, 56, 56]           --
# │    └─ActQuantProxyFromInjector: 2-39                                 [1, 32, 56, 56]           --
# │    └─ActQuantProxyFromInjector: 2-40                                 [1, 32, 56, 56]           --
# │    │    └─FusedActivationQuantProxy: 3-48                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─QuantIdentity: 1-25                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-42                                 --                        --
# │    │    └─FusedActivationQuantProxy: 3-50                            --                        --
# ├─ModuleList: 1-28                                                     --                        (recursive)
# │    └─QuantConv2d: 2-43                                               [1, 64, 56, 56]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-51                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-52                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-53                            [1, 64, 56, 56]           --
# │    └─BatchNorm2d: 2-44                                               [1, 64, 56, 56]           128
# │    └─QuantIdentity: 2-45                                             [1, 64, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-54                            [1, 64, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-55                            [1, 64, 56, 56]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-28                                                     --                        (recursive)
# │    └─QuantIdentity: 2-47                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-57                            --                        --
# │    └─MaxPool2d: 2-48                                                 [1, 64, 28, 28]           --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantConv2d: 2-49                                               [1, 32, 28, 28]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-58                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-59                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-60                            [1, 32, 28, 28]           --
# │    └─BatchNorm2d: 2-50                                               [1, 32, 28, 28]           64
# │    └─QuantIdentity: 2-51                                             [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-61                            [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-62                            [1, 32, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantIdentity: 2-53                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-64                            --                        --
# │    └─QuantConv2d: 2-54                                               [1, 64, 28, 28]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-65                            [1, 32, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-66                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-67                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-55                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-56                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-68                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-69                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantIdentity: 2-58                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-71                            --                        --
# │    └─QuantConv2d: 2-59                                               [1, 32, 28, 28]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-72                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-73                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-74                            [1, 32, 28, 28]           --
# │    └─BatchNorm2d: 2-60                                               [1, 32, 28, 28]           64
# │    └─QuantIdentity: 2-61                                             [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-75                            [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-76                            [1, 32, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantIdentity: 2-63                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-78                            --                        --
# │    └─QuantConv2d: 2-64                                               [1, 64, 28, 28]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-79                            [1, 32, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-80                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-81                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-65                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-66                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-82                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-83                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantIdentity: 2-68                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-85                            --                        --
# │    └─QuantConv2d: 2-69                                               [1, 64, 28, 28]           4,096
# │    │    └─ActQuantProxyFromInjector: 3-86                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-87                         [64, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-88                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-70                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-71                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-89                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-90                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-39                                                     --                        (recursive)
# │    └─QuantIdentity: 2-73                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-92                            --                        --
# ├─QuantIdentity: 1-40                                                  [1, 64, 28, 28]           --
# │    └─ActQuantProxyFromInjector: 2-74                                 [1, 64, 28, 28]           --
# │    └─ActQuantProxyFromInjector: 2-75                                 [1, 64, 28, 28]           --
# │    │    └─FusedActivationQuantProxy: 3-93                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─QuantIdentity: 1-42                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-77                                 --                        --
# │    │    └─FusedActivationQuantProxy: 3-95                            --                        --
# ├─ModuleList: 1-45                                                     --                        (recursive)
# │    └─QuantConv2d: 2-78                                               [1, 96, 28, 28]           55,296
# │    │    └─ActQuantProxyFromInjector: 3-96                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-97                         [96, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-98                            [1, 96, 28, 28]           --
# │    └─BatchNorm2d: 2-79                                               [1, 96, 28, 28]           192
# │    └─QuantIdentity: 2-80                                             [1, 96, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-99                            [1, 96, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-100                           [1, 96, 28, 28]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-45                                                     --                        (recursive)
# │    └─QuantIdentity: 2-82                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-102                           --                        --
# │    └─MaxPool2d: 2-83                                                 [1, 96, 14, 14]           --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantConv2d: 2-84                                               [1, 48, 14, 14]           4,608
# │    │    └─ActQuantProxyFromInjector: 3-103                           [1, 96, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-104                        [48, 96, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-105                           [1, 48, 14, 14]           --
# │    └─BatchNorm2d: 2-85                                               [1, 48, 14, 14]           96
# │    └─QuantIdentity: 2-86                                             [1, 48, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-106                           [1, 48, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-107                           [1, 48, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantIdentity: 2-88                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-109                           --                        --
# │    └─QuantConv2d: 2-89                                               [1, 96, 14, 14]           41,472
# │    │    └─ActQuantProxyFromInjector: 3-110                           [1, 48, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-111                        [96, 48, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-112                           [1, 96, 14, 14]           --
# │    └─BatchNorm2d: 2-90                                               [1, 96, 14, 14]           192
# │    └─QuantIdentity: 2-91                                             [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-113                           [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-114                           [1, 96, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantIdentity: 2-93                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-116                           --                        --
# │    └─QuantConv2d: 2-94                                               [1, 48, 14, 14]           4,608
# │    │    └─ActQuantProxyFromInjector: 3-117                           [1, 96, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-118                        [48, 96, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-119                           [1, 48, 14, 14]           --
# │    └─BatchNorm2d: 2-95                                               [1, 48, 14, 14]           96
# │    └─QuantIdentity: 2-96                                             [1, 48, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-120                           [1, 48, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-121                           [1, 48, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantIdentity: 2-98                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-123                           --                        --
# │    └─QuantConv2d: 2-99                                               [1, 96, 14, 14]           41,472
# │    │    └─ActQuantProxyFromInjector: 3-124                           [1, 48, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-125                        [96, 48, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-126                           [1, 96, 14, 14]           --
# │    └─BatchNorm2d: 2-100                                              [1, 96, 14, 14]           192
# │    └─QuantIdentity: 2-101                                            [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-127                           [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-128                           [1, 96, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantIdentity: 2-103                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-130                           --                        --
# │    └─QuantConv2d: 2-104                                              [1, 96, 14, 14]           82,944
# │    │    └─ActQuantProxyFromInjector: 3-131                           [1, 96, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-132                        [96, 96, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-133                           [1, 96, 14, 14]           --
# │    └─BatchNorm2d: 2-105                                              [1, 96, 14, 14]           192
# │    └─QuantIdentity: 2-106                                            [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-134                           [1, 96, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-135                           [1, 96, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-56                                                     --                        (recursive)
# │    └─QuantIdentity: 2-108                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-137                           --                        --
# ├─QuantIdentity: 1-57                                                  [1, 96, 14, 14]           --
# │    └─ActQuantProxyFromInjector: 2-109                                [1, 96, 14, 14]           --
# │    └─ActQuantProxyFromInjector: 2-110                                [1, 96, 14, 14]           --
# │    │    └─FusedActivationQuantProxy: 3-138                           [1, 96, 14, 14]           --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─QuantIdentity: 1-59                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-112                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-140                           --                        --
# ├─ModuleList: 1-62                                                     --                        (recursive)
# │    └─QuantConv2d: 2-113                                              [1, 128, 14, 14]          110,592
# │    │    └─ActQuantProxyFromInjector: 3-141                           [1, 96, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-142                        [128, 96, 3, 3]           --
# │    │    └─ActQuantProxyFromInjector: 3-143                           [1, 128, 14, 14]          --
# │    └─BatchNorm2d: 2-114                                              [1, 128, 14, 14]          256
# │    └─QuantIdentity: 2-115                                            [1, 128, 14, 14]          --
# │    │    └─ActQuantProxyFromInjector: 3-144                           [1, 128, 14, 14]          --
# │    │    └─ActQuantProxyFromInjector: 3-145                           [1, 128, 14, 14]          --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-62                                                     --                        (recursive)
# │    └─QuantIdentity: 2-117                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-147                           --                        --
# │    └─MaxPool2d: 2-118                                                [1, 128, 7, 7]            --
# ├─ModuleList: 1-67                                                     --                        (recursive)
# │    └─QuantConv2d: 2-119                                              [1, 128, 7, 7]            147,456
# │    │    └─ActQuantProxyFromInjector: 3-148                           [1, 128, 7, 7]            --
# │    │    └─WeightQuantProxyFromInjector: 3-149                        [128, 128, 3, 3]          --
# │    │    └─ActQuantProxyFromInjector: 3-150                           [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-120                                              [1, 128, 7, 7]            256
# │    └─QuantIdentity: 2-121                                            [1, 128, 7, 7]            --
# │    │    └─ActQuantProxyFromInjector: 3-151                           [1, 128, 7, 7]            --
# │    │    └─ActQuantProxyFromInjector: 3-152                           [1, 128, 7, 7]            --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-67                                                     --                        (recursive)
# │    └─QuantIdentity: 2-123                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-154                           --                        --
# │    └─QuantConv2d: 2-124                                              [1, 128, 7, 7]            147,456
# │    │    └─ActQuantProxyFromInjector: 3-155                           [1, 128, 7, 7]            --
# │    │    └─WeightQuantProxyFromInjector: 3-156                        [128, 128, 3, 3]          --
# │    │    └─ActQuantProxyFromInjector: 3-157                           [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-125                                              [1, 128, 7, 7]            256
# │    └─QuantIdentity: 2-126                                            [1, 128, 7, 7]            --
# │    │    └─ActQuantProxyFromInjector: 3-158                           [1, 128, 7, 7]            --
# │    │    └─ActQuantProxyFromInjector: 3-159                           [1, 128, 7, 7]            --
# ├─QuantIdentity: 1-66                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-127                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-160                           --                        --
# ├─ModuleList: 1-67                                                     --                        (recursive)
# │    └─QuantIdentity: 2-128                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-161                           --                        --
# ├─QuantIdentity: 1-68                                                  [1, 128, 7, 7]            --
# │    └─ActQuantProxyFromInjector: 2-129                                [1, 128, 7, 7]            --
# │    └─ActQuantProxyFromInjector: 2-130                                [1, 128, 7, 7]            --
# │    │    └─FusedActivationQuantProxy: 3-162                           [1, 128, 7, 7]            --
# ├─TruncAvgPool2d: 1-69                                                 [1, 128, 1, 1]            --
# │    └─TruncQuantProxyFromInjector: 2-131                              [1, 128, 1, 1]            --
# │    │    └─TruncIntQuant: 3-163                                       [1, 128, 1, 1]            --
# ├─ModuleList: 1-70                                                     --                        (recursive)
# │    └─QuantLinear: 2-132                                              [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-164                           [1, 128]                  --
# │    │    └─WeightQuantProxyFromInjector: 3-165                        [64, 128]                 8,192
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# │    └─QuantLinear: 2-134                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-167                        --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-168                           [1, 64]                   --
# │    └─BatchNorm1d: 2-135                                              [1, 64]                   128
# │    └─QuantReLU: 2-136                                                [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-169                           [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-170                           [1, 64]                   1
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# │    └─QuantReLU: 2-140                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-174                           --                        (recursive)
# │    └─QuantReLU: 2-147                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-183                           --                        (recursive)
# │    └─QuantReLU: 2-140                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-174                           --                        (recursive)
# │    └─QuantLinear: 2-141                                              [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-175                           [1, 64]                   --
# │    │    └─WeightQuantProxyFromInjector: 3-176                        [32, 64]                  2,048
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# │    └─QuantLinear: 2-143                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-178                        --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-179                           [1, 32]                   --
# │    └─BatchNorm1d: 2-144                                              [1, 32]                   64
# │    └─QuantReLU: 2-145                                                [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-180                           [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-181                           [1, 32]                   1
# │    └─QuantLinear: 2-146                                              --                        (recursive)
# │    │    └─WeightQuantProxyFromInjector: 3-182                        --                        (recursive)
# │    └─QuantReLU: 2-147                                                --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-183                           --                        (recursive)
# │    └─QuantLinear: 2-148                                              [1, 2]                    --
# │    │    └─ActQuantProxyFromInjector: 3-184                           [1, 32]                   --
# │    │    └─WeightQuantProxyFromInjector: 3-185                        [2, 32]                   64
# │    │    └─ActQuantProxyFromInjector: 3-186                           [1, 2]                    --
# │    └─TensorNorm: 2-149                                               [1, 2]                    2
# ========================================================================================================================
# Total params: 738,917
# Trainable params: 738,917
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 35.63
# Params size (MB): 0.01
# Estimated Total Size (MB): 36.24
# ========================================================================================================================

# %% [markdown]
# # Export to ONNX

# %%
torch_model.cpu();

# %%
torch_input = torch.randn(1, 3, 224, 224)
torch.onnx.export(torch_model, torch_input, "torch_cnv_deep_resnet_v2.onnx")
