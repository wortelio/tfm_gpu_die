# %%
import modules.models.model_torch_CNV_w1a1_DEEP_Resnet as torch_cnv_deep_resnet
import modules.models.model_CNV_w1a1_DEEP_Resnet as cnv_deep_resnet

import numpy as np
import torch
from torchinfo import summary

# %% [markdown]
# # Model

# %%
torch_model = torch_cnv_deep_resnet.Torch_CNV_w1a1_DEEP_Resnet().to('cpu')
brevitas_model = cnv_deep_resnet.CNV_w1a1_DEEP_Resnet().to('cpu')

# %%
torch_model.eval();
brevitas_model.eval();

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Torch

# %%
print(summary(torch_model, input_size=(1, 3, 224, 224)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Torch_CNV_w1a1_DEEP_Resnet               [1, 2]                    --
# ├─ModuleList: 1-1                        --                        --
# │    └─Conv2d: 2-1                       [1, 64, 224, 224]         1,728
# │    └─BatchNorm2d: 2-2                  [1, 64, 224, 224]         128
# │    └─ReLU: 2-3                         [1, 64, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 64, 112, 112]         --
# │    └─Conv2d: 2-5                       [1, 32, 112, 112]         18,432
# │    └─BatchNorm2d: 2-6                  [1, 32, 112, 112]         64
# │    └─ReLU: 2-7                         [1, 32, 112, 112]         --
# │    └─MaxPool2d: 2-8                    [1, 32, 56, 56]           --
# ├─ModuleList: 1-2                        --                        --
# │    └─Conv2d: 2-9                       [1, 16, 56, 56]           512
# │    └─BatchNorm2d: 2-10                 [1, 16, 56, 56]           32
# │    └─ReLU: 2-11                        [1, 16, 56, 56]           --
# │    └─Conv2d: 2-12                      [1, 32, 56, 56]           4,608
# │    └─BatchNorm2d: 2-13                 [1, 32, 56, 56]           64
# │    └─ReLU: 2-14                        [1, 32, 56, 56]           --
# │    └─Conv2d: 2-15                      [1, 32, 56, 56]           1,024
# │    └─BatchNorm2d: 2-16                 [1, 32, 56, 56]           64
# │    └─ReLU: 2-17                        [1, 32, 56, 56]           --
# ├─ReLU: 1-3                              [1, 32, 56, 56]           --
# ├─ModuleList: 1-4                        --                        --
# │    └─Conv2d: 2-18                      [1, 64, 56, 56]           18,432
# │    └─BatchNorm2d: 2-19                 [1, 64, 56, 56]           128
# │    └─ReLU: 2-20                        [1, 64, 56, 56]           --
# │    └─MaxPool2d: 2-21                   [1, 64, 28, 28]           --
# ├─ModuleList: 1-5                        --                        --
# │    └─Conv2d: 2-22                      [1, 32, 28, 28]           2,048
# │    └─BatchNorm2d: 2-23                 [1, 32, 28, 28]           64
# │    └─ReLU: 2-24                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-25                      [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-26                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-27                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-28                      [1, 32, 28, 28]           2,048
# │    └─BatchNorm2d: 2-29                 [1, 32, 28, 28]           64
# │    └─ReLU: 2-30                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-31                      [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-32                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-33                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-34                      [1, 32, 28, 28]           2,048
# │    └─BatchNorm2d: 2-35                 [1, 32, 28, 28]           64
# │    └─ReLU: 2-36                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-37                      [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-38                 [1, 64, 28, 28]           128
# │    └─ReLU: 2-39                        [1, 64, 28, 28]           --
# ├─ReLU: 1-6                              [1, 64, 28, 28]           --
# ├─ModuleList: 1-7                        --                        --
# │    └─MaxPool2d: 2-40                   [1, 64, 14, 14]           --
# ├─ModuleList: 1-8                        --                        --
# │    └─Conv2d: 2-41                      [1, 32, 14, 14]           2,048
# │    └─BatchNorm2d: 2-42                 [1, 32, 14, 14]           64
# │    └─ReLU: 2-43                        [1, 32, 14, 14]           --
# │    └─Conv2d: 2-44                      [1, 64, 14, 14]           18,432
# │    └─BatchNorm2d: 2-45                 [1, 64, 14, 14]           128
# │    └─ReLU: 2-46                        [1, 64, 14, 14]           --
# │    └─Conv2d: 2-47                      [1, 32, 14, 14]           2,048
# │    └─BatchNorm2d: 2-48                 [1, 32, 14, 14]           64
# │    └─ReLU: 2-49                        [1, 32, 14, 14]           --
# │    └─Conv2d: 2-50                      [1, 64, 14, 14]           18,432
# │    └─BatchNorm2d: 2-51                 [1, 64, 14, 14]           128
# │    └─ReLU: 2-52                        [1, 64, 14, 14]           --
# │    └─Conv2d: 2-53                      [1, 64, 14, 14]           36,864
# │    └─BatchNorm2d: 2-54                 [1, 64, 14, 14]           128
# │    └─ReLU: 2-55                        [1, 64, 14, 14]           --
# │    └─Conv2d: 2-56                      [1, 64, 14, 14]           36,864
# │    └─BatchNorm2d: 2-57                 [1, 64, 14, 14]           128
# │    └─ReLU: 2-58                        [1, 64, 14, 14]           --
# ├─ReLU: 1-9                              [1, 64, 14, 14]           --
# ├─ModuleList: 1-10                       --                        --
# │    └─MaxPool2d: 2-59                   [1, 64, 7, 7]             --
# ├─ModuleList: 1-11                       --                        --
# │    └─Conv2d: 2-60                      [1, 64, 7, 7]             36,864
# │    └─BatchNorm2d: 2-61                 [1, 64, 7, 7]             128
# │    └─ReLU: 2-62                        [1, 64, 7, 7]             --
# │    └─Conv2d: 2-63                      [1, 64, 7, 7]             36,864
# │    └─BatchNorm2d: 2-64                 [1, 64, 7, 7]             128
# │    └─ReLU: 2-65                        [1, 64, 7, 7]             --
# ├─ReLU: 1-12                             [1, 64, 7, 7]             --
# ├─AvgPool2d: 1-13                        [1, 64, 1, 1]             --
# ├─ModuleList: 1-14                       --                        --
# │    └─Linear: 2-66                      [1, 64]                   4,096
# │    └─BatchNorm1d: 2-67                 [1, 64]                   128
# │    └─ReLU: 2-68                        [1, 64]                   --
# │    └─Linear: 2-69                      [1, 32]                   2,048
# │    └─BatchNorm1d: 2-70                 [1, 32]                   64
# │    └─ReLU: 2-71                        [1, 32]                   --
# │    └─Linear: 2-72                      [1, 2]                    64
# ==========================================================================================
# Total params: 302,944
# Trainable params: 302,944
# Non-trainable params: 0
# Total mult-adds (M): 469.25
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 69.75
# Params size (MB): 1.21
# Estimated Total Size (MB): 71.56
# ==========================================================================================

# %% [markdown]
# ### Brevitas

# %%
print(summary(brevitas_model, input_size=(1, 3, 224, 224)))
# Out:
# ========================================================================================================================
# Layer (type:depth-idx)                                                 Output Shape              Param #
# ========================================================================================================================
# CNV_w1a1_DEEP_Resnet                                                   [1, 2]                    --
# ├─ModuleList: 1-7                                                      --                        (recursive)
# │    └─QuantIdentity: 2-1                                              [1, 3, 224, 224]          --
# │    │    └─ActQuantProxyFromInjector: 3-1                             [1, 3, 224, 224]          --
# │    │    └─ActQuantProxyFromInjector: 3-2                             [1, 3, 224, 224]          --
# ├─ModuleList: 1-62                                                     --                        (recursive)
# │    └─QuantIdentity: 2-127                                            --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-161                           --                        (recursive)
# ├─ModuleList: 1-7                                                      --                        (recursive)
# │    └─QuantIdentity: 2-3                                              --                        --
# │    │    └─ActQuantProxyFromInjector: 3-4                             --                        --
# │    └─QuantConv2d: 2-4                                                [1, 64, 224, 224]         1,728
# │    │    └─ActQuantProxyFromInjector: 3-5                             [1, 3, 224, 224]          --
# │    │    └─WeightQuantProxyFromInjector: 3-6                          [64, 3, 3, 3]             --
# │    │    └─ActQuantProxyFromInjector: 3-7                             [1, 64, 224, 224]         --
# │    └─BatchNorm2d: 2-5                                                [1, 64, 224, 224]         128
# │    └─QuantIdentity: 2-6                                              [1, 64, 224, 224]         --
# │    │    └─ActQuantProxyFromInjector: 3-8                             [1, 64, 224, 224]         --
# │    │    └─ActQuantProxyFromInjector: 3-9                             [1, 64, 224, 224]         --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-7                                                      --                        (recursive)
# │    └─QuantIdentity: 2-8                                              --                        --
# │    │    └─ActQuantProxyFromInjector: 3-11                            --                        --
# │    └─MaxPool2d: 2-9                                                  [1, 64, 112, 112]         --
# │    └─QuantConv2d: 2-10                                               [1, 32, 112, 112]         18,432
# │    │    └─ActQuantProxyFromInjector: 3-12                            [1, 64, 112, 112]         --
# │    │    └─WeightQuantProxyFromInjector: 3-13                         [32, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-14                            [1, 32, 112, 112]         --
# │    └─BatchNorm2d: 2-11                                               [1, 32, 112, 112]         64
# │    └─QuantIdentity: 2-12                                             [1, 32, 112, 112]         --
# │    │    └─ActQuantProxyFromInjector: 3-15                            [1, 32, 112, 112]         --
# │    │    └─ActQuantProxyFromInjector: 3-16                            [1, 32, 112, 112]         --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-7                                                      --                        (recursive)
# │    └─QuantIdentity: 2-14                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-18                            --                        --
# │    └─MaxPool2d: 2-15                                                 [1, 32, 56, 56]           --
# ├─ModuleList: 1-14                                                     --                        (recursive)
# │    └─QuantConv2d: 2-16                                               [1, 16, 56, 56]           512
# │    │    └─ActQuantProxyFromInjector: 3-19                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-20                         [16, 32, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-21                            [1, 16, 56, 56]           --
# │    └─BatchNorm2d: 2-17                                               [1, 16, 56, 56]           32
# │    └─QuantIdentity: 2-18                                             [1, 16, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-22                            [1, 16, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-23                            [1, 16, 56, 56]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-14                                                     --                        (recursive)
# │    └─QuantIdentity: 2-20                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-25                            --                        --
# │    └─QuantConv2d: 2-21                                               [1, 32, 56, 56]           4,608
# │    │    └─ActQuantProxyFromInjector: 3-26                            [1, 16, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-27                         [32, 16, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-28                            [1, 32, 56, 56]           --
# │    └─BatchNorm2d: 2-22                                               [1, 32, 56, 56]           64
# │    └─QuantIdentity: 2-23                                             [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-29                            [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-30                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-14                                                     --                        (recursive)
# │    └─QuantIdentity: 2-25                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-32                            --                        --
# │    └─QuantConv2d: 2-26                                               [1, 32, 56, 56]           1,024
# │    │    └─ActQuantProxyFromInjector: 3-33                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-34                         [32, 32, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-35                            [1, 32, 56, 56]           --
# │    └─BatchNorm2d: 2-27                                               [1, 32, 56, 56]           64
# │    └─QuantIdentity: 2-28                                             [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-36                            [1, 32, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-37                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-14                                                     --                        (recursive)
# │    └─QuantIdentity: 2-30                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-39                            --                        --
# ├─QuantIdentity: 1-15                                                  [1, 32, 56, 56]           --
# │    └─ActQuantProxyFromInjector: 2-31                                 [1, 32, 56, 56]           --
# │    └─ActQuantProxyFromInjector: 2-32                                 [1, 32, 56, 56]           --
# │    │    └─FusedActivationQuantProxy: 3-40                            [1, 32, 56, 56]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─QuantIdentity: 1-17                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-34                                 --                        --
# │    │    └─FusedActivationQuantProxy: 3-42                            --                        --
# ├─ModuleList: 1-20                                                     --                        (recursive)
# │    └─QuantConv2d: 2-35                                               [1, 64, 56, 56]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-43                            [1, 32, 56, 56]           --
# │    │    └─WeightQuantProxyFromInjector: 3-44                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-45                            [1, 64, 56, 56]           --
# │    └─BatchNorm2d: 2-36                                               [1, 64, 56, 56]           128
# │    └─QuantIdentity: 2-37                                             [1, 64, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-46                            [1, 64, 56, 56]           --
# │    │    └─ActQuantProxyFromInjector: 3-47                            [1, 64, 56, 56]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-20                                                     --                        (recursive)
# │    └─QuantIdentity: 2-39                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-49                            --                        --
# │    └─MaxPool2d: 2-40                                                 [1, 64, 28, 28]           --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantConv2d: 2-41                                               [1, 32, 28, 28]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-50                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-51                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-52                            [1, 32, 28, 28]           --
# │    └─BatchNorm2d: 2-42                                               [1, 32, 28, 28]           64
# │    └─QuantIdentity: 2-43                                             [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-53                            [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-54                            [1, 32, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-45                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-56                            --                        --
# │    └─QuantConv2d: 2-46                                               [1, 64, 28, 28]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-57                            [1, 32, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-58                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-59                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-47                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-48                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-60                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-61                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-50                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-63                            --                        --
# │    └─QuantConv2d: 2-51                                               [1, 32, 28, 28]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-64                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-65                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-66                            [1, 32, 28, 28]           --
# │    └─BatchNorm2d: 2-52                                               [1, 32, 28, 28]           64
# │    └─QuantIdentity: 2-53                                             [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-67                            [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-68                            [1, 32, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-55                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-70                            --                        --
# │    └─QuantConv2d: 2-56                                               [1, 64, 28, 28]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-71                            [1, 32, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-72                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-73                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-57                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-58                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-74                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-75                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-60                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-77                            --                        --
# │    └─QuantConv2d: 2-61                                               [1, 32, 28, 28]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-78                            [1, 64, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-79                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-80                            [1, 32, 28, 28]           --
# │    └─BatchNorm2d: 2-62                                               [1, 32, 28, 28]           64
# │    └─QuantIdentity: 2-63                                             [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-81                            [1, 32, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-82                            [1, 32, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-65                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-84                            --                        --
# │    └─QuantConv2d: 2-66                                               [1, 64, 28, 28]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-85                            [1, 32, 28, 28]           --
# │    │    └─WeightQuantProxyFromInjector: 3-86                         [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-87                            [1, 64, 28, 28]           --
# │    └─BatchNorm2d: 2-67                                               [1, 64, 28, 28]           128
# │    └─QuantIdentity: 2-68                                             [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-88                            [1, 64, 28, 28]           --
# │    │    └─ActQuantProxyFromInjector: 3-89                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-33                                                     --                        (recursive)
# │    └─QuantIdentity: 2-70                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-91                            --                        --
# ├─QuantIdentity: 1-34                                                  [1, 64, 28, 28]           --
# │    └─ActQuantProxyFromInjector: 2-71                                 [1, 64, 28, 28]           --
# │    └─ActQuantProxyFromInjector: 2-72                                 [1, 64, 28, 28]           --
# │    │    └─FusedActivationQuantProxy: 3-92                            [1, 64, 28, 28]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─QuantIdentity: 1-36                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-74                                 --                        --
# │    │    └─FusedActivationQuantProxy: 3-94                            --                        --
# ├─ModuleList: 1-37                                                     --                        --
# │    └─MaxPool2d: 2-75                                                 [1, 64, 14, 14]           --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantConv2d: 2-76                                               [1, 32, 14, 14]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-95                            [1, 64, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-96                         [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-97                            [1, 32, 14, 14]           --
# │    └─BatchNorm2d: 2-77                                               [1, 32, 14, 14]           64
# │    └─QuantIdentity: 2-78                                             [1, 32, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-98                            [1, 32, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-99                            [1, 32, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-80                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-101                           --                        --
# │    └─QuantConv2d: 2-81                                               [1, 64, 14, 14]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-102                           [1, 32, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-103                        [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-104                           [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-82                                               [1, 64, 14, 14]           128
# │    └─QuantIdentity: 2-83                                             [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-105                           [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-106                           [1, 64, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-85                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-108                           --                        --
# │    └─QuantConv2d: 2-86                                               [1, 32, 14, 14]           2,048
# │    │    └─ActQuantProxyFromInjector: 3-109                           [1, 64, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-110                        [32, 64, 1, 1]            --
# │    │    └─ActQuantProxyFromInjector: 3-111                           [1, 32, 14, 14]           --
# │    └─BatchNorm2d: 2-87                                               [1, 32, 14, 14]           64
# │    └─QuantIdentity: 2-88                                             [1, 32, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-112                           [1, 32, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-113                           [1, 32, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-90                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-115                           --                        --
# │    └─QuantConv2d: 2-91                                               [1, 64, 14, 14]           18,432
# │    │    └─ActQuantProxyFromInjector: 3-116                           [1, 32, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-117                        [64, 32, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-118                           [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-92                                               [1, 64, 14, 14]           128
# │    └─QuantIdentity: 2-93                                             [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-119                           [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-120                           [1, 64, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-95                                             --                        --
# │    │    └─ActQuantProxyFromInjector: 3-122                           --                        --
# │    └─QuantConv2d: 2-96                                               [1, 64, 14, 14]           36,864
# │    │    └─ActQuantProxyFromInjector: 3-123                           [1, 64, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-124                        [64, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-125                           [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-97                                               [1, 64, 14, 14]           128
# │    └─QuantIdentity: 2-98                                             [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-126                           [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-127                           [1, 64, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-100                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-129                           --                        --
# │    └─QuantConv2d: 2-101                                              [1, 64, 14, 14]           36,864
# │    │    └─ActQuantProxyFromInjector: 3-130                           [1, 64, 14, 14]           --
# │    │    └─WeightQuantProxyFromInjector: 3-131                        [64, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-132                           [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-102                                              [1, 64, 14, 14]           128
# │    └─QuantIdentity: 2-103                                            [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-133                           [1, 64, 14, 14]           --
# │    │    └─ActQuantProxyFromInjector: 3-134                           [1, 64, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-50                                                     --                        (recursive)
# │    └─QuantIdentity: 2-105                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-136                           --                        --
# ├─QuantIdentity: 1-51                                                  [1, 64, 14, 14]           --
# │    └─ActQuantProxyFromInjector: 2-106                                [1, 64, 14, 14]           --
# │    └─ActQuantProxyFromInjector: 2-107                                [1, 64, 14, 14]           --
# │    │    └─FusedActivationQuantProxy: 3-137                           [1, 64, 14, 14]           --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─QuantIdentity: 1-53                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-109                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-139                           --                        --
# ├─ModuleList: 1-54                                                     --                        --
# │    └─MaxPool2d: 2-110                                                [1, 64, 7, 7]             --
# ├─ModuleList: 1-59                                                     --                        (recursive)
# │    └─QuantConv2d: 2-111                                              [1, 64, 7, 7]             36,864
# │    │    └─ActQuantProxyFromInjector: 3-140                           [1, 64, 7, 7]             --
# │    │    └─WeightQuantProxyFromInjector: 3-141                        [64, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-142                           [1, 64, 7, 7]             --
# │    └─BatchNorm2d: 2-112                                              [1, 64, 7, 7]             128
# │    └─QuantIdentity: 2-113                                            [1, 64, 7, 7]             --
# │    │    └─ActQuantProxyFromInjector: 3-143                           [1, 64, 7, 7]             --
# │    │    └─ActQuantProxyFromInjector: 3-144                           [1, 64, 7, 7]             --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-59                                                     --                        (recursive)
# │    └─QuantIdentity: 2-115                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-146                           --                        --
# │    └─QuantConv2d: 2-116                                              [1, 64, 7, 7]             36,864
# │    │    └─ActQuantProxyFromInjector: 3-147                           [1, 64, 7, 7]             --
# │    │    └─WeightQuantProxyFromInjector: 3-148                        [64, 64, 3, 3]            --
# │    │    └─ActQuantProxyFromInjector: 3-149                           [1, 64, 7, 7]             --
# │    └─BatchNorm2d: 2-117                                              [1, 64, 7, 7]             128
# │    └─QuantIdentity: 2-118                                            [1, 64, 7, 7]             --
# │    │    └─ActQuantProxyFromInjector: 3-150                           [1, 64, 7, 7]             --
# │    │    └─ActQuantProxyFromInjector: 3-151                           [1, 64, 7, 7]             --
# ├─QuantIdentity: 1-58                                                  --                        --
# │    └─ActQuantProxyFromInjector: 2-119                                --                        --
# │    │    └─FusedActivationQuantProxy: 3-152                           --                        --
# ├─ModuleList: 1-59                                                     --                        (recursive)
# │    └─QuantIdentity: 2-120                                            --                        --
# │    │    └─ActQuantProxyFromInjector: 3-153                           --                        --
# ├─QuantIdentity: 1-60                                                  [1, 64, 7, 7]             --
# │    └─ActQuantProxyFromInjector: 2-121                                [1, 64, 7, 7]             --
# │    └─ActQuantProxyFromInjector: 2-122                                [1, 64, 7, 7]             --
# │    │    └─FusedActivationQuantProxy: 3-154                           [1, 64, 7, 7]             --
# ├─TruncAvgPool2d: 1-61                                                 [1, 64, 1, 1]             --
# │    └─TruncQuantProxyFromInjector: 2-123                              [1, 64, 1, 1]             --
# │    │    └─TruncIntQuant: 3-155                                       [1, 64, 1, 1]             --
# ├─ModuleList: 1-62                                                     --                        (recursive)
# │    └─QuantLinear: 2-124                                              [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-156                           [1, 64]                   --
# │    │    └─WeightQuantProxyFromInjector: 3-157                        [64, 64]                  4,096
# │    │    └─ActQuantProxyFromInjector: 3-158                           [1, 64]                   --
# │    └─BatchNorm1d: 2-125                                              [1, 64]                   128
# │    └─QuantIdentity: 2-126                                            [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-159                           [1, 64]                   --
# │    │    └─ActQuantProxyFromInjector: 3-160                           [1, 64]                   1
# │    └─QuantIdentity: 2-127                                            --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-161                           --                        (recursive)
# │    └─QuantIdentity: 2-128                                            --                        (recursive)
# │    │    └─ActQuantProxyFromInjector: 3-162                           --                        (recursive)
# │    └─QuantLinear: 2-129                                              [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-163                           [1, 64]                   --
# │    │    └─WeightQuantProxyFromInjector: 3-164                        [32, 64]                  2,048
# │    │    └─ActQuantProxyFromInjector: 3-165                           [1, 32]                   --
# │    └─BatchNorm1d: 2-130                                              [1, 32]                   64
# │    └─QuantIdentity: 2-131                                            [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-166                           [1, 32]                   --
# │    │    └─ActQuantProxyFromInjector: 3-167                           [1, 32]                   1
# │    └─QuantLinear: 2-132                                              [1, 2]                    --
# │    │    └─ActQuantProxyFromInjector: 3-168                           [1, 32]                   --
# │    │    └─WeightQuantProxyFromInjector: 3-169                        [2, 32]                   64
# │    │    └─ActQuantProxyFromInjector: 3-170                           [1, 2]                    --
# │    └─TensorNorm: 2-133                                               [1, 2]                    2
# ========================================================================================================================
# Total params: 302,948
# Trainable params: 302,948
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 34.87
# Params size (MB): 0.01
# Estimated Total Size (MB): 35.48
# ========================================================================================================================
# /opt/conda/envs/pytorch_brevitas/lib/python3.10/site-packages/torch/_tensor.py:1362: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400410390/work/c10/core/TensorImpl.h:1900.)
#   return super().rename(names)

# %% [markdown]
# # Export to ONNX

# %%
# model.cpu();

# %%
# torch_input = torch.randn(1, 3, 224, 224)
# torch.onnx.export(model, torch_input, "torch_cnv_deep_resnet.onnx")
