# %%
import copy
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# # Define Matplot Style

# %%
#mpl.style.use('seaborn-v0_8')
#mpl.style.use('seaborn-v0_8-bright')
#mpl.style.use('ggplot')

# %%
imgs_folder = './images_model_size/aimet_dfire_old_style_matplot/'

# %% [markdown]
# # Model Definition

# %% [markdown]
# ### Original FP32 Model

# %%
model = {
    'conv1' : {
        'in': 3,
        'out': 32,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv2' : {
        'in': 32,
        'out': 16,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv31' : {
        'in': 16,
        'out': 16,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv32' : {
        'in': 16,
        'out': 32,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv33' : {
        'in': 32,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv34' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv41' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv42' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv43' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv44' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv45' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv46' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'linear51' : {
        'in': 64,
        'out': 16,
        'layer_size': 'small'
    },
    'linear52' : {
        'in': 16,
        'out': 2,
        'layer_size': 'small'
    }
}

# %% [markdown]
# ### Pruning after SVD HIGH

# %%
model_HIGH_cp_after_svd = {
    'conv1' : {
        'in': 3,
        'out': 22,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv20' : {
        'in': 22,
        'out': 6,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv21' : {
        'in': 6,
        'out': 16,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv31' : {
        'in': 16,
        'out': 14,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv320' : {
        'in': 14,
        'out': 16,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv321' : {
        'in': 16,
        'out': 32,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv33' : {
        'in': 28,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True,
    },
    'conv340' : {
        'in': 32,
        'out': 30,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv341' : {
        'in': 30,
        'out': 64,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv41' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv42' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv43' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv440' : {
        'in': 32,
        'out': 39,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv441' : {
        'in': 39,
        'out': 64,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv45' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv460' : {
        'in': 32,
        'out': 12,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv461' : {
        'in': 12,
        'out': 64,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'linear51' : {
        'in': 64,
        'out': 16,
        'layer_size': 'small'
    },
    'linear52' : {
        'in': 16,
        'out': 2,
        'layer_size': 'small'
    }
}

# %% [markdown]
# ### Pruning after SVD LOW

# %%
model_LOW_cp_after_svd = {
    'conv1' : {
        'in': 3,
        'out': 22,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv20' : {
        'in': 22,
        'out': 7,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv21' : {
        'in': 7,
        'out': 14,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv31' : {
        'in': 14,
        'out': 14,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv320' : {
        'in': 14,
        'out': 22,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv321' : {
        'in': 22,
        'out': 28,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv33' : {
        'in': 28,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True,
    },
    'conv34' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv41' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv42' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv43' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv44' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv45' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv460' : {
        'in': 32,
        'out': 7,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv461' : {
        'in': 7,
        'out': 64,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'linear51' : {
        'in': 64,
        'out': 16,
        'layer_size': 'small'
    },
    'linear52' : {
        'in': 16,
        'out': 2,
        'layer_size': 'small'
    }
}

# %% [markdown]
# ### Pruning after SVD MEDIUM

# %%
model_MED_cp_after_svd = {
    'conv1' : {
        'in': 3,
        'out': 22,
        'kernel': 3,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv20' : {
        'in': 22,
        'out': 6,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv21' : {
        'in': 6,
        'out': 14,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv31' : {
        'in': 14,
        'out': 8,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv320' : {
        'in': 8,
        'out': 11,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv321' : {
        'in': 11,
        'out': 25,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'conv33' : {
        'in': 25,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True,
    },
    'conv34' : {
        'in': 32,
        'out': 57,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv41' : {
        'in': 57,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv42' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv43' : {
        'in': 64,
        'out': 32,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv44' : {
        'in': 32,
        'out': 64,
        'kernel': 3,
        'layer_size': 'big',
        'is_bias': True
    },
    'conv45' : {
        'in': 64,
        'out': 28,
        'kernel': 1,
        'layer_size': 'small',
        'is_bias': True
    },
    'conv460' : {
        'in': 28,
        'out': 6,
        'kernel': (3, 1),
        'layer_size': 'small',
        'is_bias': False
    },
    'conv461' : {
        'in': 6,
        'out': 64,
        'kernel': (1, 3),
        'layer_size': 'small',
        'is_bias': True
    },
    'linear51' : {
        'in': 64,
        'out': 16,
        'layer_size': 'small'
    },
    'linear52' : {
        'in': 16,
        'out': 2,
        'layer_size': 'small'
    }
}

# %% [markdown]
# # Print Model

# %%
def print_model(model_dic):
    for k in model_dic.keys():
        print(k)
        for kin, v in model_dic[k].items():
            print(f'\t{kin:<15}: ' + str(v).rjust(8))

# %% [markdown]
# ### Original FP32 model, no SVD, no Pruning

# %%
print_model(model)
# Out:
# conv1
# 	in             :        3
# 	out            :       32
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv2
# 	in             :       32
# 	out            :       16
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv31
# 	in             :       16
# 	out            :       16
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv32
# 	in             :       16
# 	out            :       32
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv33
# 	in             :       32
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv34
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv46
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small

# %% [markdown]
# ### Agressive SVD and Pruning

# %%
print_model(model_HIGH_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv20
# 	in             :       22
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv21
# 	in             :        6
# 	out            :       16
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv31
# 	in             :       16
# 	out            :       14
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv320
# 	in             :       14
# 	out            :       16
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv321
# 	in             :       16
# 	out            :       32
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv33
# 	in             :       28
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv340
# 	in             :       32
# 	out            :       30
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv341
# 	in             :       30
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv440
# 	in             :       32
# 	out            :       39
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv441
# 	in             :       39
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv460
# 	in             :       32
# 	out            :       12
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv461
# 	in             :       12
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small

# %% [markdown]
# ### LOW SVD and Pruning

# %%
print_model(model_LOW_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv20
# 	in             :       22
# 	out            :        7
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv21
# 	in             :        7
# 	out            :       14
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv31
# 	in             :       14
# 	out            :       14
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv320
# 	in             :       14
# 	out            :       22
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv321
# 	in             :       22
# 	out            :       28
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv33
# 	in             :       28
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv34
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv460
# 	in             :       32
# 	out            :        7
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv461
# 	in             :        7
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small

# %% [markdown]
# ### Medium SVD and Pruning

# %%
print_model(model_MED_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# conv20
# 	in             :       22
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv21
# 	in             :        6
# 	out            :       14
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv31
# 	in             :       14
# 	out            :        8
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv320
# 	in             :        8
# 	out            :       11
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv321
# 	in             :       11
# 	out            :       25
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# conv33
# 	in             :       25
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv34
# 	in             :       32
# 	out            :       57
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv41
# 	in             :       57
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# conv45
# 	in             :       64
# 	out            :       28
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# conv460
# 	in             :       28
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# conv461
# 	in             :        6
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small

# %% [markdown]
# # Functions to Calculate Conv and Linear Size

# %%
def conv_size(conv_dic):
    '''
    Calculates number of weights and bias
        - weights = kernel**2 * in * out
        - bias = out
    - return: number of weights, number of bias
    '''
    if isinstance(conv_dic['kernel'], int):
        return (
            (conv_dic['kernel']**2) * conv_dic['in']  * conv_dic['out'], 
            conv_dic['out'] if conv_dic['is_bias'] else 0
        )
    elif isinstance(conv_dic['kernel'], tuple):
        return (
            (conv_dic['kernel'][0]*conv_dic['kernel'][1]) * conv_dic['in']  * conv_dic['out'], 
            conv_dic['out'] if conv_dic['is_bias'] else 0 
        )
    else:
        print("Kernel is not well defined")
        
def linear_size(linear_dic):
    '''
    Calculates number of weights and bias
        - weights = in * out
        - bias = out
    - return: number of weights, number of bias
    '''
    return linear_dic['in'] * linear_dic['out'],  linear_dic['out']

# %% [markdown]
# # Update Model Dic with Weights and Bias

# %%
def add_weights_bias(model):
    for k in model.keys():
        if 'conv' in k:
            weights, bias = conv_size(model[k])
            model[k].update({'weights': weights, 'bias': bias})
        elif 'linear' in k:
            weights, bias = linear_size(model[k])
            model[k].update({'weights': weights, 'bias': bias})
        else:
            print('Wrong layer name')

# %% [markdown]
# ### FP32 Model

# %%
add_weights_bias(model)
print_model(model)
# Out:
# conv1
# 	in             :        3
# 	out            :       32
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      864
# 	bias           :       32
# conv2
# 	in             :       32
# 	out            :       16
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     4608
# 	bias           :       16
# conv31
# 	in             :       16
# 	out            :       16
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      256
# 	bias           :       16
# conv32
# 	in             :       16
# 	out            :       32
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     4608
# 	bias           :       32
# conv33
# 	in             :       32
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1024
# 	bias           :       32
# conv34
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv46
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# 	weights        :     1024
# 	bias           :       16
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small
# 	weights        :       32
# 	bias           :        2

# %% [markdown]
# ### Agressive SVD and Pruning

# %%
add_weights_bias(model_HIGH_cp_after_svd)
print_model(model_HIGH_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      594
# 	bias           :       22
# conv20
# 	in             :       22
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      396
# 	bias           :        0
# conv21
# 	in             :        6
# 	out            :       16
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      288
# 	bias           :       16
# conv31
# 	in             :       16
# 	out            :       14
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      224
# 	bias           :       14
# conv320
# 	in             :       14
# 	out            :       16
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      672
# 	bias           :        0
# conv321
# 	in             :       16
# 	out            :       32
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1536
# 	bias           :       32
# conv33
# 	in             :       28
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      896
# 	bias           :       32
# conv340
# 	in             :       32
# 	out            :       30
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :     2880
# 	bias           :        0
# conv341
# 	in             :       30
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     5760
# 	bias           :       64
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv440
# 	in             :       32
# 	out            :       39
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :     3744
# 	bias           :        0
# conv441
# 	in             :       39
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     7488
# 	bias           :       64
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv460
# 	in             :       32
# 	out            :       12
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :     1152
# 	bias           :        0
# conv461
# 	in             :       12
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2304
# 	bias           :       64
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# 	weights        :     1024
# 	bias           :       16
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small
# 	weights        :       32
# 	bias           :        2

# %% [markdown]
# ### LOW SVD and Pruning

# %%
add_weights_bias(model_LOW_cp_after_svd)
print_model(model_LOW_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      594
# 	bias           :       22
# conv20
# 	in             :       22
# 	out            :        7
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      462
# 	bias           :        0
# conv21
# 	in             :        7
# 	out            :       14
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      294
# 	bias           :       14
# conv31
# 	in             :       14
# 	out            :       14
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      196
# 	bias           :       14
# conv320
# 	in             :       14
# 	out            :       22
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      924
# 	bias           :        0
# conv321
# 	in             :       22
# 	out            :       28
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1848
# 	bias           :       28
# conv33
# 	in             :       28
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      896
# 	bias           :       32
# conv34
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv41
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv45
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv460
# 	in             :       32
# 	out            :        7
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      672
# 	bias           :        0
# conv461
# 	in             :        7
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1344
# 	bias           :       64
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# 	weights        :     1024
# 	bias           :       16
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small
# 	weights        :       32
# 	bias           :        2

# %% [markdown]
# ### MEDIUM SVD and Pruning

# %%
add_weights_bias(model_MED_cp_after_svd)
print_model(model_MED_cp_after_svd)
# Out:
# conv1
# 	in             :        3
# 	out            :       22
# 	kernel         :        3
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      594
# 	bias           :       22
# conv20
# 	in             :       22
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      396
# 	bias           :        0
# conv21
# 	in             :        6
# 	out            :       14
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      252
# 	bias           :       14
# conv31
# 	in             :       14
# 	out            :        8
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      112
# 	bias           :        8
# conv320
# 	in             :        8
# 	out            :       11
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      264
# 	bias           :        0
# conv321
# 	in             :       11
# 	out            :       25
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      825
# 	bias           :       25
# conv33
# 	in             :       25
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :      800
# 	bias           :       32
# conv34
# 	in             :       32
# 	out            :       57
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    16416
# 	bias           :       57
# conv41
# 	in             :       57
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1824
# 	bias           :       32
# conv42
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv43
# 	in             :       64
# 	out            :       32
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     2048
# 	bias           :       32
# conv44
# 	in             :       32
# 	out            :       64
# 	kernel         :        3
# 	layer_size     :      big
# 	is_bias        :     True
# 	weights        :    18432
# 	bias           :       64
# conv45
# 	in             :       64
# 	out            :       28
# 	kernel         :        1
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1792
# 	bias           :       28
# conv460
# 	in             :       28
# 	out            :        6
# 	kernel         :   (3, 1)
# 	layer_size     :    small
# 	is_bias        :    False
# 	weights        :      504
# 	bias           :        0
# conv461
# 	in             :        6
# 	out            :       64
# 	kernel         :   (1, 3)
# 	layer_size     :    small
# 	is_bias        :     True
# 	weights        :     1152
# 	bias           :       64
# linear51
# 	in             :       64
# 	out            :       16
# 	layer_size     :    small
# 	weights        :     1024
# 	bias           :       16
# linear52
# 	in             :       16
# 	out            :        2
# 	layer_size     :    small
# 	weights        :       32
# 	bias           :        2

# %% [markdown]
# # Calculate Number of Weights for Small and Big Layers

# %%
def small_big_weights_number(model_dic):
    small_weights = 0
    big_weights = 0
    for k in model_dic.keys():
        if model_dic[k]['layer_size'] == 'small':
            small_weights += model_dic[k]['weights'] 
        elif model_dic[k]['layer_size'] == 'big':
            big_weights += model_dic[k]['weights'] 
        else:
            print("Error: layer size is not well defined")

    return small_weights, big_weights

# %% [markdown]
# # Pie Comparing Weights Portion of Small and Big Layers

# %% [markdown]
# ### Before AIMET

# %%
labels = ['Small Layers', 'Big Layers']

small_weights, big_weights = small_big_weights_number(model)

fig, ax = plt.subplots(figsize=(4,3))
ax.pie([small_weights, big_weights], labels = labels, autopct='%.0f%%', startangle=45)
ax.set_title("Weights Distribution of Big and Small Layers")
fig.savefig(imgs_folder + 'weights_percentage.png')

# %% [markdown]
# ### After Agressive AIMET

# %%
labels = ['Small Layers', 'Big Layers']

small_weights, big_weights = small_big_weights_number(model_HIGH_cp_after_svd)

fig, ax = plt.subplots(figsize=(4,3))
ax.pie([small_weights, big_weights], labels = labels, autopct='%.0f%%', startangle=45)
ax.set_title("Weights Distribution of Big and Small Layers")
fig.savefig(imgs_folder + 'aimet_weights_percentage.png')

# %% [markdown]
# ### After Low AIMET

# %%
labels = ['Small Layers', 'Big Layers']

small_weights, big_weights = small_big_weights_number(model_LOW_cp_after_svd)

fig, ax = plt.subplots(figsize=(4,3))
ax.pie([small_weights, big_weights], labels = labels, autopct='%.0f%%', startangle=45)
ax.set_title("Weights Distribution of Big and Small Layers")
fig.savefig(imgs_folder + 'aimet_weights_percentage.png')

# %% [markdown]
# ### After Medium AIMET

# %%
labels = ['Small Layers', 'Big Layers']

small_weights, big_weights = small_big_weights_number(model_MED_cp_after_svd)

fig, ax = plt.subplots(figsize=(4,3))
ax.pie([small_weights, big_weights], labels = labels, autopct='%.0f%%', startangle=45)
ax.set_title("Weights Distribution of Big and Small Layers")
fig.savefig(imgs_folder + 'aimet_weights_percentage.png')

# %% [markdown]
# # Calculate Size of Each Layer

# %%
def add_layer_size(model_dic, small_size, big_size, bias_size):

    model = copy.deepcopy(model_dic)
    for k in model.keys():
        bias_bits = model[k]['bias'] * bias_size
        weights_bits = 0
        if model[k]['layer_size'] == "small":
            weights_bits = model[k]['weights'] * small_size
        elif model[k]['layer_size'] == "big":
            weights_bits = model[k]['weights'] * big_size
        else:
            print('Wrong layer type: small or big')
        
        model[k].update({'weights_bits': weights_bits, 'bias_bits': bias_bits})

    return model

# %%
#model1 = add_layer_size(model, wb_small_1, wb_big_1, bias_bits)
#print_model(model1)

# %% [markdown]
# # Bits Overview

# %%
def get_layers_total_bits(model):
    '''
    Compute total bits summing each layer. It returns separated layers bits too.

    Return:
        - total bits
        - total bits of small layers
        - total bits of big layers
        - total bits of bias
    '''
    
    small_layers_bits = 0
    big_layers_bits = 0
    bias_bits = 0
    
    for k in model.keys():
        if model[k]['layer_size'] == 'small':
            small_layers_bits += model[k]['weights_bits'] 
        elif model[k]['layer_size'] == 'big':
            big_layers_bits += model[k]['weights_bits'] 
        bias_bits += model[k]['bias_bits']

    return {
        'total': small_layers_bits + big_layers_bits + bias_bits,
        'small': small_layers_bits,
        'big': big_layers_bits,
        'bias': bias_bits
    }

# %% [markdown]
# # Comparing Models

# %% [markdown]
# ### Defining some models

# %%
# Model 1: NO COMPRESSION
wb_small_1 = 4
wb_big_1 = 2
bias_bits_1 = 4
model_name_1 = f'No Comp\nw{str(wb_small_1)}w{str(wb_big_1)}'

# Model 2: LOW COMPRESSION
wb_small_2 = 4
wb_big_2 = 3
bias_bits_2 = 8
model_name_2 = f'Low\nw{str(wb_small_2)}W{str(wb_big_2)}'

# Model 3: MEDIUM COMPRESSION
wb_small_3 = 4
wb_big_3 = 3
bias_bits_3 = 4
model_name_3 = f'Med\nw{str(wb_small_3)}W{str(wb_big_3)}'

# Model 4: HIGH COMPRESSION
wb_small_4 = 4
wb_big_4 = 4
bias_bits_4 = 4
model_name_4 = f'High\nw{str(wb_small_4)}W{str(wb_big_4)}'

# %% [markdown]
# ### Calculating Bits

# %%
model1 = add_layer_size(model, wb_small_1, wb_big_1, bias_bits_1)
model2 = add_layer_size(model_LOW_cp_after_svd, wb_small_2, wb_big_2, bias_bits_2)
model3 = add_layer_size(model_MED_cp_after_svd, wb_small_3, wb_big_3, bias_bits_3)
model4 = add_layer_size(model_HIGH_cp_after_svd, wb_small_4, wb_big_4, bias_bits_4)

# %% [markdown]
# ### Manual set up of conv34 for LOW Model

# %%
model2['conv34'].update({'weights_bits': model2['conv34']['weights']*2})
model2['conv34']
# Out:
# {'in': 32,
#  'out': 64,
#  'kernel': 3,
#  'layer_size': 'big',
#  'is_bias': True,
#  'weights': 18432,
#  'bias': 64,
#  'weights_bits': 36864,
#  'bias_bits': 512}

# %% [markdown]
# ### Manual set up of conv34 for MEDIUM Model

# %%
# model3['conv34'].update({'weights_bits': model3['conv34']['weights']*3})
# print(model3['conv34'])
# model3['conv42'].update({'weights_bits': model3['conv42']['weights']*3})
# print(model3['conv42'])

# %% [markdown]
# ### Bits for all Models

# %%
model_bits_1 = get_layers_total_bits(model1)
model_bits_2 = get_layers_total_bits(model2)
model_bits_3 = get_layers_total_bits(model3)
model_bits_4 = get_layers_total_bits(model4)

# %% [markdown]
# ## Some Plots

# %%
#xticks = ['Model1', 'Model2', 'Model3', 'Model4']
xticks = [model_name_1, model_name_2, model_name_3, model_name_4] 
yticks = [model_bits_1['total'], model_bits_2['total'], model_bits_3['total'], model_bits_4['total']]
print(yticks)
# Out:
# [223688, 209016, 208156, 216208]

# %%
fig, ax = plt.subplots(layout='constrained', figsize=(6,4))
ax.bar(xticks, yticks)
ax.set_ylabel("Number of bits")
ax.set_title("Number of bits for different Weights Configurations")
fig.savefig(imgs_folder + 'bits_number.png')

# %% [markdown]
# # Bars

# %%
xticks = (model_name_1, model_name_2, model_name_3, model_name_4)
yticks = {
    'Small': np.round(np.array([model_bits_1['small'], 
                                model_bits_2['small'], 
                                model_bits_3['small'], 
                                model_bits_4['small']])/(8*1024), decimals=1),
    'Big': np.round(np.array([model_bits_1['big'], 
                              model_bits_2['big'], 
                              model_bits_3['big'], 
                              model_bits_4['big']])/(8*1024), decimals=1),
    'Total': np.round(np.array([model_bits_1['total'], 
                                model_bits_2['total'], 
                                model_bits_3['total'], 
                                model_bits_4['total']])/(8*1024), decimals=1),
}

x = np.arange(len(xticks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(6,4))
for k, v in yticks.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, v, width, label=k)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('KB')
ax.set_title("KB for different Weights Configurations")
ax.set_xticks(x + width, xticks)
ax.legend(loc='upper right', ncols=3)
ax.set_ylim(0, 35)
ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', alpha=0.3)
ax.xaxis.grid(color='gray', alpha=0.3)

fig.savefig(imgs_folder + 'KB_total_small_big.png')
plt.show()

# %%
xticks = (model_name_1, model_name_2, model_name_3, model_name_4)
yticks = {
    'Small': np.round(np.array([model_bits_1['small'], model_bits_2['small'], model_bits_3['small'], model_bits_4['small']])/8000, decimals=1),
    'Big': np.round(np.array([model_bits_1['big'], model_bits_2['big'], model_bits_3['big'], model_bits_4['big']])/8000, decimals=1),
}

width = 0.5  # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(6,4))
bottom = np.zeros(4)

for k, v in yticks.items():
    p = ax.bar(xticks, v, width, label=k, bottom=bottom)
    bottom += v

    ax.bar_label(p, label_type='center')

ax.set_title('KB for different Weights Configurations')
ax.set_ylabel('KB')
ax.set_ylim(0, 35)
ax.legend(ncols=2)

fig.savefig(imgs_folder + 'KB_small_big.png')
plt.show()

# %% [markdown]
# # Pies to view the impact of small, big and bias

# %%
labels = ['Small Layers', 'Big Layers', 'Bias']

fig, ax = plt.subplots(2, 2, figsize=(5,5))

plt.subplot(2, 2, 1)
size = [model_bits_1['small'], model_bits_1['big'], model_bits_1['bias']] 
plt.pie(size, labels = labels, startangle=45)
plt.title(model_name_1)

plt.subplot(2, 2, 2)
size = [model_bits_2['small'], model_bits_2['big'], model_bits_2['bias']] 
plt.pie(size, labels = labels, startangle=45)
plt.title(model_name_2)

plt.subplot(2, 2, 3)
size = [model_bits_3['small'], model_bits_3['big'], model_bits_3['bias']] 
plt.pie(size, labels = labels, startangle=45)
plt.title(model_name_3)

plt.subplot(2, 2, 4)
size = [model_bits_4['small'], model_bits_4['big'], model_bits_4['bias']] 
plt.pie(size, labels = labels, startangle=45)
plt.title(model_name_4)

plt.tight_layout(pad=2)
fig.savefig(imgs_folder + 'bits_pies.png')
plt.show()
