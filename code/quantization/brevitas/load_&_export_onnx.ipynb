# %%
import os

import numpy as np
import math
import random

import torch

import torch.nn as nn 
from torch.nn.utils import parameters_to_vector
import torch.optim as optim
from torchinfo import summary

from brevitas.export import export_onnx_qcdq

import config_aimet
import models_aimet_medium_fasdd
import models
import utils
import datasets
import metrics
import loss
import val_epoch

# %%
if config_aimet.MODEL == "BED":
    
    print("Using Fixed Point Quantizers without BN")
    quant_model = models_aimet_medium_fasdd.QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER(
            weight_bw = config_aimet.WEIGHTS_BIT_WIDTH,
            big_layers_weight_bw = config_aimet.BIG_LAYERS_WEIGHTS_BIT_WIDTH,
            act_bw = config_aimet.ACTIVATIONS_BIT_WIDTH,
            bias_bw = config_aimet.BIAS_BIT_WIDTH,
            num_classes=config_aimet.N_CLASSES).to(config_aimet.DEVICE)
    # quant_model = models.QUANT_FixedPoint_NoBN_BED_CLASSIFIER(
    #         weight_bw = config_aimet.WEIGHTS_BIT_WIDTH,
    #         big_layers_weight_bw = config_aimet.BIG_LAYERS_WEIGHTS_BIT_WIDTH,
    #         act_bw = config_aimet.ACTIVATIONS_BIT_WIDTH,
    #         bias_bw = config_aimet.BIAS_BIT_WIDTH,
    #         num_classes=config_aimet.N_CLASSES).to(config_aimet.DEVICE)

else:
    print("Wrong Model")
    raise SystemExit("Wrong Model")

optimizer = optim.Adam(quant_model.parameters(), 
                       lr=config_aimet.LEARNING_RATE, 
                       weight_decay=config_aimet.WEIGHT_DECAY)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 
                                                 mode='min',
                                                 factor=config_aimet.FACTOR, 
                                                 patience=config_aimet.PATIENCE, 
                                                 threshold=config_aimet.THRES, 
                                                 threshold_mode='abs',
                                                 min_lr=config_aimet.MIN_LR)

# MODEL PARAMETERS
n_trainable = sum(p.numel() for p in quant_model.parameters() if p.requires_grad)
print(f'\nTrainable parameters = {n_trainable}')

n_params = parameters_to_vector(quant_model.parameters()).numel()
print(f'Total parameters = {n_params}\n')
# Out:
# Using Fixed Point Quantizers without BN
#
# Trainable parameters = 63631
# Total parameters = 63631

# %% [markdown]
# ## Model Medium Compression

# %%
# model_dir = 'experiments_fuseBN_256_fasdd/test_v10_MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
# model_file = model_dir + 'BED_classifier__best_mean_F1.pt'
# epochs_trained = utils.load_checkpoint(model_file, quant_model, optimizer, scheduler, config_aimet.DEVICE)

# %% [markdown]
# ### Model with Medium Compression: conv341 defined as big layer

# %%
# model_dir = 'experiments_fuseBN_256_fasdd/test_v11_MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
# model_file = model_dir + 'BED_classifier__smoke__precision=0.9096__recall=0.8942__epoch=93.pt'
# epochs_trained = utils.load_checkpoint(model_file, quant_model, optimizer, scheduler, config_aimet.DEVICE)

# %% [markdown]
# ### FASDD VAL added: Model with Medium Compression: conv341 defined as big layer

# %%
model_dir = 'experiments_fuseBN_256_fasdd/test_v30_FASDD_VAL__MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
model_file = model_dir + 'BED_classifier__best_mean_F1.pt'
epochs_trained = utils.load_checkpoint(model_file, quant_model, optimizer, scheduler, config_aimet.DEVICE)
# Out:
# Loading Model. Trained during 94 epochs

# %% [markdown]
# ## Model with No Compression

# %%
# model_dir = 'experiments_fuseBN_256_fasdd/test_v00_NoCOMP_w4W2a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
# model_file = model_dir + 'BED_classifier__best_smoke__precision=0.9217__epoch=59.pt'
# epochs_trained = utils.load_checkpoint(model_file, quant_model, optimizer, scheduler, config_aimet.DEVICE)

# %% [markdown]
# # Evaluate Brevitas Quant Model

# %% [markdown]
# ## Dataset

# %%
val_loader = datasets.get_val_loader()
# Out:
# TEST DFire dataset
# DFire Removed wrong images: 0
# DFire empty images: 2005
# DFire only smoke images: 1186
# DFire only fire images: 220
# DFire smoke and fire images: 895
#
# Test dataset len: 4306
#
# TEST FASDD UAV dataset
# FASDD Removed wrong images: 0
# FASDD empty images: 1997
# FASDD only smoke images: 846
# FASDD only fire images: 35
# FASDD smoke and fire images: 1303
#
# Test FASDD UAV dataset len: 4181
#
# TEST FASDD CV dataset
# FASDD Removed wrong images: 0
# FASDD empty images: 6533
# FASDD only smoke images: 3902
# FASDD only fire images: 2091
# FASDD smoke and fire images: 3358
#
# Test FASDD CV dataset len: 15884
# Concatenate Test DFire and FASDD UAV datasets
# Test dataset len: 8487
# Concatenate with FASDD CV dataset
# Test dataset len: 24371

# %% [markdown]
# ## Loss
# Needed for evaluation function

# %%
if config_aimet.LOSS_FN == "BCE":
    print(f'Loss Function: BCE')
    print(f'Smoke Precision Weight: {config_aimet.SMOKE_PRECISION_WEIGHT}')
    loss_fn = loss.BCE_LOSS(device=config_aimet.DEVICE, smoke_precision_weight=config_aimet.SMOKE_PRECISION_WEIGHT)
else:
    print("Wrong loss function")
    raise SystemExit("Wrong loss function")
# Out:
# Loss Function: BCE
# Smoke Precision Weight: 0.8

# %%
quant_model.eval()
with torch.no_grad():
    val_losses, val_metrics = val_epoch.eval_fn(
        loader=val_loader, 
        model=quant_model,                         
        loss_fn=loss_fn,
        device=config_aimet.DEVICE)
# Out:
# Validating:   0%|                                                                                                                     | 0/380 [00:00<?, ?it/s]/opt/conda/envs/pytorch_brevitas/lib/python3.10/site-packages/torch/_tensor.py:1362: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400410390/work/c10/core/TensorImpl.h:1900.)
#   return super().rename(names)
# Validating: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 380/380 [00:54<00:00,  6.93it/s]
# Total Loss  |Smoke Loss  |Fire Loss
# ------------ ------------ ------------
# 16.312      |10.550      |5.762
# SMOKE -> Precision: 0.950 - Recall: 0.897 - Accuracy: 0.929 - F1: 0.923
# FIRE -> Precision: 0.926 - Recall: 0.974 - Accuracy: 0.966 - F1: 0.950

# %%
for k, v in val_metrics.items():
    print(f'{k}: smoke {v[0]:.4f} - fire: {v[1]:.4f}')
print(f'F1 Mean: {(val_metrics["F1"][0] + val_metrics["F1"][1])/2:.4f}')
# Out:
# Accuracy: smoke 0.9292 - fire: 0.9665
# Precision: smoke 0.9499 - fire: 0.9262
# Recall: smoke 0.8971 - fire: 0.9743
# F1: smoke 0.9227 - fire: 0.9496
# F1 Mean: 0.9362

# %% [markdown]
# # Model to CPU and ONNX Export

# %%
quant_model.to('cpu')
print("Model to CPU before exports")
# Out:
# Model to CPU before exports

# %%
# export_onnx_qcdq(
#     quant_model, 
#     torch.randn(1, 3, config_aimet.IMG_H, config_aimet.IMG_W).to('cpu'), 
#     export_path='./models/onnx_export/medium_fassd__conv341_big__epoch=93.onnx')
# Out:
# /opt/conda/envs/pytorch_brevitas/lib/python3.10/site-packages/brevitas/export/onnx/standard/manager.py:26: UserWarning: ONNX opset version set to 13, override with opset_version=
#   warnings.warn(f"ONNX opset version set to {DEFAULT_OPSET}, override with {ka}=")

# %% [markdown]
# # Export to QONNX, previous step to FINN-ONNX

# %%
from brevitas.export import export_qonnx

# %%
export_qonnx(
    quant_model, 
    export_path='./experiments_fuseBN_256_fasdd/test_v30_FASDD_VAL__MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/BED__med_comp__341_big__best_mean_f1__cpu__QONNX.onnx',
    input_t=torch.randn(1, 3, config_aimet.IMG_H, config_aimet.IMG_W).to('cpu') 
)
# Out:
# ir_version: 8
# producer_name: "pytorch"
# producer_version: "2.1.2"
# graph {
#   node {
#     input: "x.1823"
#     input: "/model/input0/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/input0/act_quant/export_handler/Quant_output_0"
#     name: "/model/input0/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv1.bias"
#     input: "/model/conv1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/input0/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv1/Conv_output_0"
#     name: "/model/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv1/Conv_output_0"
#     output: "/model/relu1/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu1/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu1/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu1/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu1/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu1/act_quant/export_handler/Quant_output_0"
#     output: "/model/maxpool2/MaxPool_output_0"
#     name: "/model/maxpool2/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv2/conv2.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv2/conv2.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv2/conv2.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv2/conv2.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/maxpool2/MaxPool_output_0"
#     input: "/model/conv2/conv2.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/conv2/conv2.0/Conv_output_0"
#     name: "/model/conv2/conv2.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv2/conv2.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv2/conv2.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv2/conv2.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv2/conv2.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv2.1.bias"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv2/conv2.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv2/conv2.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv2/conv2.0/Conv_output_0"
#     input: "/model/conv2/conv2.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv2/conv2.1/Conv_output_0"
#     name: "/model/conv2/conv2.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv2/conv2.1/Conv_output_0"
#     output: "/model/relu2/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu2/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu2/act_quant/activation_impl/Relu_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu2/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu2/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu2/act_quant/export_handler/Quant_output_0"
#     output: "/model/maxpool3/MaxPool_output_0"
#     name: "/model/maxpool3/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv31/conv31.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv31/conv31.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv31/conv31.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv31/conv31.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/maxpool3/MaxPool_output_0"
#     input: "/model/conv31/conv31.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/conv31/conv31.0/Conv_output_0"
#     name: "/model/conv31/conv31.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv31/conv31.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv31/conv31.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv31/conv31.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv31/conv31.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv31.1.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv31/conv31.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv31/conv31.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv31/conv31.0/Conv_output_0"
#     input: "/model/conv31/conv31.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv31/conv31.1/Conv_output_0"
#     name: "/model/conv31/conv31.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv31/conv31.1/Conv_output_0"
#     output: "/model/relu31/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu31/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu31/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu31/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu31/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv32/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv32/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv32/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv32/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv32.bias"
#     input: "/model/conv1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv32/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv32/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu31/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv32/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv32/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv32/Conv_output_0"
#     name: "/model/conv32/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv32/Conv_output_0"
#     output: "/model/relu32/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu32/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu32/act_quant/activation_impl/Relu_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu32/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu32/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv33/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv33/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv33/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv33/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv33.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv33/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv33/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu32/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv33/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv33/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv33/Conv_output_0"
#     name: "/model/conv33/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv33/Conv_output_0"
#     output: "/model/relu33/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu33/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu33/act_quant/activation_impl/Relu_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu33/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu33/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv34/conv34.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv34/conv34.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv34/conv34.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv34/conv34.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu33/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv34/conv34.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/conv34/conv34.0/Conv_output_0"
#     name: "/model/conv34/conv34.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv34/conv34.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv34/conv34.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv34.1.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv34/conv34.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv34/conv34.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv34/conv34.0/Conv_output_0"
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv34/conv34.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv34/conv34.1/Conv_output_0"
#     name: "/model/conv34/conv34.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv34/conv34.1/Conv_output_0"
#     output: "/model/relu34/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu34/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu34/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu34/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu34/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu34/act_quant/export_handler/Quant_output_0"
#     output: "/model/maxpool4/MaxPool_output_0"
#     name: "/model/maxpool4/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv41/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv41/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv41/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv41/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv41.bias"
#     input: "/model/conv1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv41/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv41/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/maxpool4/MaxPool_output_0"
#     input: "/model/conv41/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv41/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv41/Conv_output_0"
#     name: "/model/conv41/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv41/Conv_output_0"
#     output: "/model/relu41/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu41/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu41/act_quant/activation_impl/Relu_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu41/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu41/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv42/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv42/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv42/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv42/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv42.bias"
#     input: "/model/conv1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv42/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv42/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu41/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv42/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv42/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv42/Conv_output_0"
#     name: "/model/conv42/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv42/Conv_output_0"
#     output: "/model/relu42/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu42/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu42/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu42/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu42/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv43/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv43/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv43/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv43/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv43.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv43/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv43/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu42/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv43/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv43/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv43/Conv_output_0"
#     name: "/model/conv43/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv43/Conv_output_0"
#     output: "/model/relu43/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu43/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu43/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu43/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu43/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv44/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv44/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv34/conv34.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv44/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv44/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv44.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv44/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv44/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu43/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv44/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv44/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv44/Conv_output_0"
#     name: "/model/conv44/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv44/Conv_output_0"
#     output: "/model/relu44/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu44/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu44/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu44/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu44/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv45/conv45.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv45/conv45.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv45/conv45.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv45/conv45.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu44/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv45/conv45.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/conv45/conv45.0/Conv_output_0"
#     name: "/model/conv45/conv45.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv45/conv45.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv45/conv45.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv45/conv45.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv45/conv45.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv45.1.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv45/conv45.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv45/conv45.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv45/conv45.0/Conv_output_0"
#     input: "/model/conv45/conv45.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv45/conv45.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv45/conv45.1/Conv_output_0"
#     name: "/model/conv45/conv45.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv45/conv45.1/Conv_output_0"
#     output: "/model/relu45/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu45/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu45/act_quant/activation_impl/Relu_output_0"
#     input: "/model/relu1/act_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu45/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu45/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv46/conv46.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv46/conv46.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv46/conv46.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv46/conv46.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu45/act_quant/export_handler/Quant_output_0"
#     input: "/model/conv46/conv46.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/conv46/conv46.0/Conv_output_0"
#     name: "/model/conv46/conv46.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv46/conv46.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/conv46/conv46.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv46/conv46.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/conv46/conv46.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.conv46.1.bias"
#     input: "/model/conv31/conv31.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/conv1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/conv46/conv46.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/conv46/conv46.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/conv46/conv46.0/Conv_output_0"
#     input: "/model/conv46/conv46.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/conv46/conv46.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/conv46/conv46.1/Conv_output_0"
#     name: "/model/conv46/conv46.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/conv46/conv46.1/Conv_output_0"
#     output: "/model/relu46/act_quant/activation_impl/Relu_output_0"
#     name: "/model/relu46/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/relu46/act_quant/activation_impl/Relu_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/relu46/act_quant/export_handler/Quant_output_0"
#     name: "/model/relu46/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/relu46/act_quant/export_handler/Quant_output_0"
#     output: "/model/avgpool5/AveragePool_output_0"
#     name: "/model/avgpool5/AveragePool"
#     op_type: "AveragePool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "count_include_pad"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 28
#       ints: 28
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/avgpool5/AveragePool_output_0"
#     input: "/model/avgpool5/Constant_output_0"
#     output: "/model/avgpool5/Mul_output_0"
#     name: "/model/avgpool5/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/model/avgpool5/Mul_output_0"
#     input: "/model/conv2/conv2.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/input0/act_quant/export_handler/Constant_2_output_0"
#     input: "onnx.brevitas::Trunc_186"
#     input: "/model/input0/act_quant/export_handler/Constant_output_0"
#     output: "/model/avgpool5/trunc_quant/export_handler/Trunc_output_0"
#     name: "/model/avgpool5/trunc_quant/export_handler/Trunc"
#     op_type: "Trunc"
#     attribute {
#       name: "rounding_mode"
#       s: "round"
#       type: STRING
#     }
#     domain: "onnx.brevitas"
#   }
# ...
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu1/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 224
#           }
#           dim {
#             dim_value: 224
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv2/conv2.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv2/conv2.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv2/conv2.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu2/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 112
#           }
#           dim {
#             dim_value: 112
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv31/conv31.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv31/conv31.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv31/conv31.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu31/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv32/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv32/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu32/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv33/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv33/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu33/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv34/conv34.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv34/conv34.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv34/conv34.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu34/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv41/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv41/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu41/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv42/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv42/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu42/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv43/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv43/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu43/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv44/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv44/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu44/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv45/conv45.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv45/conv45.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv45/conv45.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu45/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv46/conv46.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv46/conv46.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/conv46/conv46.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu46/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/avgpool5/trunc_quant/export_handler/Trunc_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/linear51/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/linear51/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/relu5/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/linear52/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/linear52/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 17
# }
# opset_import {
#   domain: "onnx.brevitas"
#   version: 1
# }
