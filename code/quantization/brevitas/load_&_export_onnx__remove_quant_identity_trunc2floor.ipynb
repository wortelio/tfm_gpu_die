# %%
import os

import numpy as np
import math
import random

import torch

import torch.nn as nn 
from torch.nn.utils import parameters_to_vector
import torch.optim as optim
from torchinfo import summary

from brevitas.export import export_onnx_qcdq

import config_aimet
import models_aimet_medium_fasdd
import models
import utils
import datasets
import metrics
import loss
import val_epoch

# %% [markdown]
# # Load Model

# %%
if config_aimet.MODEL == "BED":
    
    print("Using Fixed Point Quantizers without BN")
    quant_model = models_aimet_medium_fasdd.QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER(
            weight_bw = config_aimet.WEIGHTS_BIT_WIDTH,
            big_layers_weight_bw = config_aimet.BIG_LAYERS_WEIGHTS_BIT_WIDTH,
            act_bw = config_aimet.ACTIVATIONS_BIT_WIDTH,
            bias_bw = config_aimet.BIAS_BIT_WIDTH,
            num_classes=config_aimet.N_CLASSES).to(config_aimet.DEVICE)
else:
    print("Wrong Model")
    raise SystemExit("Wrong Model")

# MODEL PARAMETERS
n_trainable = sum(p.numel() for p in quant_model.parameters() if p.requires_grad)
print(f'\nTrainable parameters = {n_trainable}')

n_params = parameters_to_vector(quant_model.parameters()).numel()
print(f'Total parameters = {n_params}\n')
# Out:
# Using Fixed Point Quantizers without BN
#
# Trainable parameters = 63631
# Total parameters = 63631

# %% [markdown]
# ### FASDD VAL added: Model with Medium Compression: conv341 defined as big layer

# %%
model_dir = 'experiments_fuseBN_256_fasdd/test_v30_FASDD_VAL__MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
model_file = model_dir + 'BED_classifier__best_mean_F1.pt'
epochs_trained = utils.load_checkpoint(
    model_file, 
    quant_model, 
    optimizer=None, 
    scheduler=None, 
    device=config_aimet.DEVICE)
# Out:
# Loading Model. Trained during 94 epochs

# %% [markdown]
# ### FASDD VAL added: Model with No Compression

# %%
# model_dir = 'experiments_fuseBN_256_fasdd/test_v21_FASDD_VAL__NoCOMP_w4W2a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/weights/'
# model_file = model_dir + 'BED_classifier__best_mean_F1.pt'
# epochs_trained = utils.load_checkpoint(model_file, quant_model, optimizer=None, scheduler=None, device=config_aimet.DEVICE)

# %% [markdown]
# ### Model to Eval Mode

# %%
quant_model.eval()
print("Model to eval mode")
# Out:
# Model to eval mode

# %% [markdown]
# ## Remove Quant Identity Layer from the Start

# %%
class QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity(nn.Module):
    def __init__(self, base_model):
        super(QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity, self).__init__()
        self.model = nn.Sequential(*list(base_model.children())[0][1:])

    def forward(self, x):
        x = self.model(x)
        return x

# %%
no_identity_model = QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity(quant_model)

# %%
no_identity_model.eval()
print("Model to eval mode")
# Out:
# Model to eval mode

# %% [markdown]
# # Compare Weights and Bias

# %%
torch.allclose(quant_model.model.conv1.bias, no_identity_model.model[0].bias)
#print(quant_model.model.conv1.weight)
# Out:
# True

# %% [markdown]
# # Evaluate Brevitas Quant Model

# %% [markdown]
# ## Dataset

# %%
val_loader = datasets.get_val_loader()
# Out:
# TEST DFire dataset
# DFire Removed wrong images: 0
# DFire empty images: 2005
# DFire only smoke images: 1186
# DFire only fire images: 220
# DFire smoke and fire images: 895
#
# Test dataset len: 4306
#
# TEST FASDD UAV dataset
# FASDD Removed wrong images: 0
# FASDD empty images: 1997
# FASDD only smoke images: 846
# FASDD only fire images: 35
# FASDD smoke and fire images: 1303
#
# Test FASDD UAV dataset len: 4181
#
# TEST FASDD CV dataset
# FASDD Removed wrong images: 0
# FASDD empty images: 6533
# FASDD only smoke images: 3902
# FASDD only fire images: 2091
# FASDD smoke and fire images: 3358
#
# Test FASDD CV dataset len: 15884
# Concatenate Test DFire and FASDD UAV datasets
# Test dataset len: 8487
# Concatenate with FASDD CV dataset
# Test dataset len: 24371

# %% [markdown]
# ## Loss
# Needed for evaluation function

# %%
if config_aimet.LOSS_FN == "BCE":
    print(f'Loss Function: BCE')
    print(f'Smoke Precision Weight: {config_aimet.SMOKE_PRECISION_WEIGHT}')
    loss_fn = loss.BCE_LOSS(device=config_aimet.DEVICE, smoke_precision_weight=config_aimet.SMOKE_PRECISION_WEIGHT)
else:
    print("Wrong loss function")
    raise SystemExit("Wrong loss function")
# Out:
# Loss Function: BCE
# Smoke Precision Weight: 0.8

# %% [markdown]
# ## Quant Model Evaluation

# %%
quant_model.eval()
with torch.no_grad():
    val_losses, val_metrics = val_epoch.eval_fn(
        loader=val_loader, 
        model=quant_model,                         
        loss_fn=loss_fn,
        device=config_aimet.DEVICE)
# Out:
# Validating:   0%|                                                                                                                                                    | 0/380 [00:00<?, ?it/s]/opt/conda/envs/pytorch_brevitas/lib/python3.10/site-packages/torch/_tensor.py:1362: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400410390/work/c10/core/TensorImpl.h:1900.)
#   return super().rename(names)
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 380/380 [00:34<00:00, 11.12it/s]
# Total Loss  |Smoke Loss  |Fire Loss
# ------------ ------------ ------------
# 16.603      |10.941      |5.662
# SMOKE -> Precision: 0.955 - Recall: 0.885 - Accuracy: 0.926 - F1: 0.919
# FIRE -> Precision: 0.930 - Recall: 0.971 - Accuracy: 0.967 - F1: 0.950

# %%
for k, v in val_metrics.items():
    print(f'{k}: smoke {v[0]:.4f} - fire: {v[1]:.4f}')
print(f'F1 Mean: {(val_metrics["F1"][0] + val_metrics["F1"][1])/2:.4f}')
# Out:
# Accuracy: smoke 0.9263 - fire: 0.9669
# Precision: smoke 0.9551 - fire: 0.9302
# Recall: smoke 0.8853 - fire: 0.9707
# F1: smoke 0.9189 - fire: 0.9500
# F1 Mean: 0.9345

# %% [markdown]
# ## No Identity Model Evaluation

# %%
no_identity_model.eval()
with torch.no_grad():
    val_losses, val_metrics = val_epoch.eval_fn(
        loader=val_loader, 
        model=no_identity_model,                         
        loss_fn=loss_fn,
        device=config_aimet.DEVICE)
# Out:
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 380/380 [00:33<00:00, 11.19it/s]
# Total Loss  |Smoke Loss  |Fire Loss
# ------------ ------------ ------------
# 16.603      |10.941      |5.662
# SMOKE -> Precision: 0.955 - Recall: 0.885 - Accuracy: 0.926 - F1: 0.919
# FIRE -> Precision: 0.930 - Recall: 0.971 - Accuracy: 0.967 - F1: 0.950

# %%
for k, v in val_metrics.items():
    print(f'{k}: smoke {v[0]:.4f} - fire: {v[1]:.4f}')
print(f'F1 Mean: {(val_metrics["F1"][0] + val_metrics["F1"][1])/2:.4f}')
# Out:
# Accuracy: smoke 0.9263 - fire: 0.9669
# Precision: smoke 0.9551 - fire: 0.9302
# Recall: smoke 0.8853 - fire: 0.9707
# F1: smoke 0.9189 - fire: 0.9500
# F1 Mean: 0.9345

# %% [markdown]
# # Model to CPU and ONNX Export

# %%
# quant_model.to('cpu')
# print("Model to CPU before exports")

# %%
# export_onnx_qcdq(
#     quant_model, 
#     torch.randn(1, 3, config_aimet.IMG_H, config_aimet.IMG_W).to('cpu'), 
#     export_path='./models/onnx_export/medium_fassd__conv341_big__epoch=93.onnx')

# %% [markdown]
# # Export to QONNX, previous step to FINN-ONNX

# %%
from brevitas.export import export_qonnx

# %%
no_identity_model.cpu()
print("Moved to CPU")
# Out:
# Moved to CPU

# %% [markdown]
# ### Export Function

# %%
export_qonnx(
    no_identity_model, 
    export_path='./experiments_fuseBN_256_fasdd/test_v30_FASDD_VAL__MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/BED_classifier__med_comp__NO_Identity__FLOOR__QONNX_OPSET_9.onnx',
    input_t=torch.randn(1, 3, config_aimet.IMG_H, config_aimet.IMG_W).to('cpu') 
)
# Out:
# ir_version: 8
# producer_name: "pytorch"
# producer_version: "2.1.2"
# graph {
#   node {
#     input: "/model/model.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.0.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.0/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "x.13"
#     input: "/model/model.0/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.0/Conv_output_0"
#     name: "/model/model.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.0/Conv_output_0"
#     output: "/model/model.1/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.1/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.1/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.1/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.3/MaxPool_output_0"
#     name: "/model/model.3/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.3/MaxPool_output_0"
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.4/model.4.0/Conv_output_0"
#     name: "/model/model.4/model.4.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.4.1.bias"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.4/model.4.0/Conv_output_0"
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.4/model.4.1/Conv_output_0"
#     name: "/model/model.4/model.4.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.1/Conv_output_0"
#     output: "/model/model.5/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.5/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.5/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.5/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.7/MaxPool_output_0"
#     name: "/model/model.7/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.7/MaxPool_output_0"
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.8/model.8.0/Conv_output_0"
#     name: "/model/model.8/model.8.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.8.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.8/model.8.0/Conv_output_0"
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.8/model.8.1/Conv_output_0"
#     name: "/model/model.8/model.8.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.1/Conv_output_0"
#     output: "/model/model.9/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.9/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.9/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.9/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.10/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.10/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.10/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.10.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.10/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.10/Conv_output_0"
#     name: "/model/model.10/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.10/Conv_output_0"
#     output: "/model/model.11/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.11/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.11/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.11/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.12/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.12/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.12/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.12.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.12/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.12/Conv_output_0"
#     name: "/model/model.12/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.12/Conv_output_0"
#     output: "/model/model.13/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.13/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.13/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.13/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.14/model.14.0/Conv_output_0"
#     name: "/model/model.14/model.14.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.14.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.14/model.14.0/Conv_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.14/model.14.1/Conv_output_0"
#     name: "/model/model.14/model.14.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.14/model.14.1/Conv_output_0"
#     output: "/model/model.15/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.15/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.15/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.15/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.16/MaxPool_output_0"
#     name: "/model/model.16/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.17/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.17/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.17/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.17.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.17/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.16/MaxPool_output_0"
#     input: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.17/Conv_output_0"
#     name: "/model/model.17/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.17/Conv_output_0"
#     output: "/model/model.18/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.18/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.18/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.18/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.19/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.19/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.19/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.19.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.19/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.19/Conv_output_0"
#     name: "/model/model.19/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.19/Conv_output_0"
#     output: "/model/model.20/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.20/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.20/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.20/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.21/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.21/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.21/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.21.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.21/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.21/Conv_output_0"
#     name: "/model/model.21/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.21/Conv_output_0"
#     output: "/model/model.22/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.22/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.22/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.22/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.23/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.23/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.23/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.23.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.23/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.23/Conv_output_0"
#     name: "/model/model.23/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.23/Conv_output_0"
#     output: "/model/model.24/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.24/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.24/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.24/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.25/model.25.0/Conv_output_0"
#     name: "/model/model.25/model.25.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.25.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.25/model.25.0/Conv_output_0"
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.25/model.25.1/Conv_output_0"
#     name: "/model/model.25/model.25.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.25/model.25.1/Conv_output_0"
#     output: "/model/model.26/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.26/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.26/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.26/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.27/model.27.0/Conv_output_0"
#     name: "/model/model.27/model.27.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.27.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.27/model.27.0/Conv_output_0"
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.27/model.27.1/Conv_output_0"
#     name: "/model/model.27/model.27.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.27/model.27.1/Conv_output_0"
#     output: "/model/model.28/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.28/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.28/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.28/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.29/AveragePool_output_0"
#     name: "/model/model.29/AveragePool"
#     op_type: "AveragePool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "count_include_pad"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 28
#       ints: 28
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.29/AveragePool_output_0"
#     input: "/model/model.29/Constant_output_0"
#     output: "/model/model.29/Mul_output_0"
#     name: "/model/model.29/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/model/model.29/Mul_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "onnx.brevitas::Trunc_184"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.29/trunc_quant/export_handler/Trunc_output_0"
# ...
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 224
#           }
#           dim {
#             dim_value: 224
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 112
#           }
#           dim {
#             dim_value: 112
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.29/trunc_quant/export_handler/Trunc_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.32/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.32/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.33/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.34/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.34/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 17
# }
# opset_import {
#   domain: "onnx.brevitas"
#   version: 1
# }

# %% [markdown]
# # New Model with BIPOLAR output

# %%
import brevitas.nn as qnn

# %%
class QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity__BIPOLAR_Out(nn.Module):
    def __init__(self, base_model):
        super(QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity__BIPOLAR_Out, self).__init__()
        self.model = nn.Sequential(*list(base_model.children())[0][1:])
        self.qnt_output = qnn.QuantIdentity(
            quant_type='binary', 
            scaling_impl_type='const',
            bit_width=1, min_val=-1.0, max_val=1.0)

    def forward(self, x):
        x = self.model(x)
        x = self.qnt_output(x)
        return x

# %%
no_identity_bipolar_out_model = QUANT_MEDIUM_PRUNING_AFTER_SVD_CLASSIFIER_NO_QuantIdentity__BIPOLAR_Out(quant_model).to(config_aimet.DEVICE)

# %% [markdown]
# ## New Val Function to test BIPOLAR Out

# %%
from tqdm import tqdm

def eval_bipolar_fn(loader, model, device):
    
    model.eval()
    loop = tqdm(loader, desc='Validating', leave=True)

    for batch_idx, (x, y) in enumerate(loop):
        x, y = x.to(device), y.to(device)
        yhat = model(x)

        yhat[yhat < 1] = 0
    
        metrics.precision_metric.update(yhat, y)
        metrics.recall_metric.update(yhat, y)
        metrics.accuracy_metric.update(yhat, y)
        metrics.f1_metric.update(yhat, y)
   
    precision = metrics.precision_metric.compute()
    recall = metrics.recall_metric.compute()
    accuracy = metrics.accuracy_metric.compute()
    f1 = metrics.f1_metric.compute()
    
    metrics.precision_metric.reset()
    metrics.recall_metric.reset()
    metrics.accuracy_metric.reset()
    metrics.f1_metric.reset()

    print(f'SMOKE -> Precision: {precision[0]:.4f} - Recall: {recall[0]:.4f} - Accuracy: {accuracy[0]:.4f} - F1: {f1[0]:.4f}')
    print(f'FIRE -> Precision: {precision[1]:.4f} - Recall: {recall[1]:.4f} - Accuracy: {accuracy[1]:.4f} - F1: {f1[1]:.4f}')
    
    return (
        {
        'Accuracy': [accuracy[0].item(), accuracy[1].item()],
        'Precision': [precision[0].item(), precision[1].item()],
        'Recall': [recall[0].item(), recall[1].item()],
        'F1': [f1[0].item(), f1[1].item()] 
        }
    )

# %%
no_identity_bipolar_out_model.eval()
with torch.no_grad():
    val_metrics = eval_bipolar_fn(
        loader=val_loader, 
        model=no_identity_bipolar_out_model,                         
        device=config_aimet.DEVICE)
# Out:
# Validating: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 380/380 [00:34<00:00, 11.12it/s]
# SMOKE -> Precision: 0.9550 - Recall: 0.8857 - Accuracy: 0.9264 - F1: 0.9190
# FIRE -> Precision: 0.9302 - Recall: 0.9707 - Accuracy: 0.9669 - F1: 0.9500

# %%
for k, v in val_metrics.items():
    print(f'{k}: smoke {v[0]:.4f} - fire: {v[1]:.4f}')
print(f'F1 Mean: {(val_metrics["F1"][0] + val_metrics["F1"][1])/2:.4f}')
# Out:
# Accuracy: smoke 0.9264 - fire: 0.9669
# Precision: smoke 0.9550 - fire: 0.9302
# Recall: smoke 0.8857 - fire: 0.9707
# F1: smoke 0.9190 - fire: 0.9500
# F1 Mean: 0.9345

# %% [markdown]
# # Export to QONNX

# %%
no_identity_bipolar_out_model.cpu()
print("Moved to CPU")
# Out:
# Moved to CPU

# %% [markdown]
# ### Export Function

# %%
export_qonnx(
    no_identity_bipolar_out_model, 
    export_path='./experiments_fuseBN_256_fasdd/test_v30_FASDD_VAL__MED_w4W3a8b4_FxdPnt_MSE_PerChnlW_IntBiasIntScl/BED_classifier__med_comp__NO_Identity__BIPOLAR__FLOOR__QONNX.onnx',
    input_t=torch.randn(1, 3, config_aimet.IMG_H, config_aimet.IMG_W).to('cpu') 
)
# Out:
# ir_version: 8
# producer_name: "pytorch"
# producer_version: "2.1.2"
# graph {
#   node {
#     input: "/model/model.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.0.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.0/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "x.13"
#     input: "/model/model.0/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.0/Conv_output_0"
#     name: "/model/model.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.0/Conv_output_0"
#     output: "/model/model.1/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.1/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.1/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.1/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.3/MaxPool_output_0"
#     name: "/model/model.3/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.3/MaxPool_output_0"
#     input: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.4/model.4.0/Conv_output_0"
#     name: "/model/model.4/model.4.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.4.1.bias"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.4/model.4.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.4/model.4.0/Conv_output_0"
#     input: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.4/model.4.1/Conv_output_0"
#     name: "/model/model.4/model.4.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.4/model.4.1/Conv_output_0"
#     output: "/model/model.5/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.5/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.5/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.5/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.7/MaxPool_output_0"
#     name: "/model/model.7/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.7/MaxPool_output_0"
#     input: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.8/model.8.0/Conv_output_0"
#     name: "/model/model.8/model.8.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.8.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.8/model.8.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.8/model.8.0/Conv_output_0"
#     input: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.8/model.8.1/Conv_output_0"
#     name: "/model/model.8/model.8.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.8/model.8.1/Conv_output_0"
#     output: "/model/model.9/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.9/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.9/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.9/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.10/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.10/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.10/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.10.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.10/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.10/Conv_output_0"
#     name: "/model/model.10/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.10/Conv_output_0"
#     output: "/model/model.11/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.11/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.11/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.11/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.12/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.12/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.12/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.12.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.12/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.12/Conv_output_0"
#     name: "/model/model.12/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.12/Conv_output_0"
#     output: "/model/model.13/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.13/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.13/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.13/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.14/model.14.0/Conv_output_0"
#     name: "/model/model.14/model.14.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_2_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.14.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.14/model.14.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.14/model.14.0/Conv_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.14/model.14.1/Conv_output_0"
#     name: "/model/model.14/model.14.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.14/model.14.1/Conv_output_0"
#     output: "/model/model.15/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.15/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.15/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.15/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.16/MaxPool_output_0"
#     name: "/model/model.16/MaxPool"
#     op_type: "MaxPool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.17/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.17/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.17/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.17.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.17/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.16/MaxPool_output_0"
#     input: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.17/Conv_output_0"
#     name: "/model/model.17/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.17/Conv_output_0"
#     output: "/model/model.18/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.18/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.18/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.18/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.19/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.19/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.19/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.19.bias"
#     input: "/model/model.0/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.19/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.19/Conv_output_0"
#     name: "/model/model.19/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.19/Conv_output_0"
#     output: "/model/model.20/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.20/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.20/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.20/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.21/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.21/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.21/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.21.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.21/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.21/Conv_output_0"
#     name: "/model/model.21/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.21/Conv_output_0"
#     output: "/model/model.22/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.22/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.22/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.22/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.23/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.23/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.14/model.14.1/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.23/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.23.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.23/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.23/Conv_output_0"
#     name: "/model/model.23/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.23/Conv_output_0"
#     output: "/model/model.24/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.24/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.24/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.24/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.25/model.25.0/Conv_output_0"
#     name: "/model/model.25/model.25.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.25.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.25/model.25.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.25/model.25.0/Conv_output_0"
#     input: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.25/model.25.1/Conv_output_0"
#     name: "/model/model.25/model.25.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.25/model.25.1/Conv_output_0"
#     output: "/model/model.26/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.26/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.26/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.26/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.0/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     input: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     output: "/model/model.27/model.27.0/Conv_output_0"
#     name: "/model/model.27/model.27.0/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 0
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Constant_output_0"
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "model.27.1.bias"
#     input: "/model/model.8/model.8.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_output_0"
#     output: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     name: "/model/model.27/model.27.1/bias_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.27/model.27.0/Conv_output_0"
#     input: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     input: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     output: "/model/model.27/model.27.1/Conv_output_0"
#     name: "/model/model.27/model.27.1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.27/model.27.1/Conv_output_0"
#     output: "/model/model.28/act_quant/activation_impl/Relu_output_0"
#     name: "/model/model.28/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/model/model.28/act_quant/activation_impl/Relu_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     name: "/model/model.28/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     output: "/model/model.29/AveragePool_output_0"
#     name: "/model/model.29/AveragePool"
#     op_type: "AveragePool"
#     attribute {
#       name: "ceil_mode"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "count_include_pad"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 28
#       ints: 28
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/model/model.29/AveragePool_output_0"
#     input: "/model/model.29/Constant_output_0"
#     output: "/model/model.29/Mul_output_0"
#     name: "/model/model.29/Mul"
#     op_type: "Mul"
#   }
#   node {
#     input: "/model/model.29/Mul_output_0"
#     input: "/model/model.4/model.4.1/bias_quant/export_handler/Constant_output_0"
#     input: "/model/model.0/weight_quant/export_handler/Constant_3_output_0"
#     input: "onnx.brevitas::Trunc_184"
#     input: "/model/model.1/act_quant/export_handler/Constant_output_0"
#     output: "/model/model.29/trunc_quant/export_handler/Trunc_output_0"
# ...
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.0/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.1/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 224
#           }
#           dim {
#             dim_value: 224
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 19
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.4/model.4.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 14
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.5/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 112
#           }
#           dim {
#             dim_value: 112
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 14
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.8/model.8.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 11
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.9/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.10/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 11
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.10/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.11/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.12/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.12/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.13/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 45
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.14/model.14.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.15/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 56
#           }
#           dim {
#             dim_value: 56
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.17/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.17/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.18/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.19/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.19/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.20/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.21/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.21/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.22/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.23/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.23/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 57
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.24/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 57
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 17
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.25/model.25.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.26/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.0/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.27/model.27.1/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.28/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 28
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.29/trunc_quant/export_handler/Trunc_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.32/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.32/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.33/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.34/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/model/model.34/bias_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 17
# }
# opset_import {
#   domain: "onnx.brevitas"
#   version: 1
# }
